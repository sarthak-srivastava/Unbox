# %%
import requests
from pprint import pprint

# %%
text_analytics_base_url = "https://southeastasia.api.cognitive.microsoft.com/text/analytics/v2.0/"

# %%
subscription_key = 'bed5d202ad2342fabdad64f1174c71a4'
assert subscription_key

# %%
key_phrase_api_url = text_analytics_base_url + "keyPhrases"
print(key_phrase_api_url)
# Out:
# https://southeastasia.api.cognitive.microsoft.com/text/analytics/v2.0/keyPhrases

# %%
#Data
documents = {'documents':[
{'id': 'iphoneX', 'text': 'The Apple iPhone X is one of the most groundbreaking launches from Apple as far as both technology and design are concerned. Each and every department is richly fed with the most that you could get. And since the new iPhone 10 loses the home button and the fingerprint scanner on it, the FaceID is what replaces it, big time.'},
{'id': 'LGG6', 'text': 'The LG G6 is another powerful flagship smartphone from the house of LG, which has been extremely generous in providing the Indian smartphone market with a large number of great quality flagship smartphones one after the other. This smartphone feeds from a powerful processor and a great camera quality. So if you want to own a flagship smartphone, there wouldn�t have been any better option than this LG.'},
{'id': 'Iphone8', 'text': 'Apple has always followed a norm of manufacturing smartphones a notch better than the previous one. The iPhone 8 too is far better than its predecessor in ways more than one. The configuration and the battery are the best so far among all iPhones. So if you are in love with this high-end brand, and are prepared to shell out huge bucks, you can buy this one. '},
{'id': 'Iphone7', 'text': 'The Apple iPhone 7 is definitely a beauty worth beholding. But this time the beauty comes with a larger brain. Powered by the most powerful processor so far and the latest iOS, the smartphone indeed solves your tasks in a jiffy. The amazing camera, larger battery backup, wide arrayed connectivity options and a bag full of patented features, makes this flagship a good buy.'},
{'id': 'IphoneSE', 'text': 'The iPhone SE is targeted to the users who would still like to go with a smaller version of the Apple\'s newiPhone 6-series smartphones. If you have liked the previous iPhone 5-series smartphones and want to enjoy the same goodness again with upgraded features, this one worth your attention.'},
{'id': 'Iphone6s', 'text': 'The premium phone comes at a premium price tag. With a decent performing configuration, dazzling looks, wide arrayed connectivity and a bag full of patented features, the flagship device is a good buy. If you have liked the previous iPhone 5-series smartphones, iPhone SE worth your attention'},
{'id': 'Pixel2', 'text': 'After the success of the Nexus series, Google is back with a bang with Pixel XL, which is a powerful device with a good pair of cameras. The excellent display properties would make the users fall in love with it. However, the device lacks little features at such high price. But if you have a craze of using the latest version of Android OS, do give it a check.'},
{'id': 'Pixel', 'text': 'After the success of the Nexus series, Google is back with a bang with Pixel series, consisting of Pixel and Pixel XL, which is a powerful device with a good pair of cameras. However, the device lacks little features at such high price. But, the performance and a  good pair of cameras make it an obvious option if you have a craze of using the latest version of Android OS, do give it a check'},
{'id': 'GalaxyS8', 'text': 'The Samsung Galaxy S8 is the new flagship phone from the korean tech giant. It offers many of the best features and specification currently in demand by the consumers. Thus, if you are looking to buy a splendid smartphone with budget not being a barrier, you can wait for the release of this one.'},
{'id': 'GalaxyNote8', 'text': 'Albeit expensive, the Samsung Galaxy Note 8 can easily be termed as the best smartphone in the market. Equipped with great photography capabilities, sound performance, curved display, S-Pen and wireless charging support, the smartphone is worthy of its high price tag.'},
{'id': 'GalaxyA8+', 'text': 'The Samsung Galaxy A8 Plus 2018 can aptly be called a perfect blend of a tablet and a smartphone, termed as a phablet. This device is a powerhouse in terms of performance and storage. The cameras are praiseworthy and the selfie camera is the major highlight. Moreover, the battery backup of the device tends to improve with quick charging feature. Overall, it is a power-packed device to deliver some great smartphone experience to its users.'},
{'id': 'GalaxyC9Pro', 'text': 'Samsung Galaxy C9 Pro comes packed with all powerful features, including the processor, battery, great display, etc. However, the cameras tends to steal the show, compared to its peers. So if want to own a premium smartphone, this is probably the one you need to choose.'},
{'id': 'GalaxyC7', 'text': 'The Samsung Galaxy C7 Pro has everything to be a midrange flagship by a trustworthy brand. Its full scaled hardware and elegant metal outfit enlist this smartphone among the top smartphone contenders. It is perfect for an avid photographer as well as a selfie fanatic. Connectivity wise it does not seem to lack behind either. The only issue is the lower pixel density, but considering its budget it can be overlooked.'},
{'id': 'GalaxyJ7', 'text': 'If you have been waiting for a phablet from the Korean electronics giant, the Samsung Galaxy J7 2015 is here. It falls in the mid range portfolio and will expand Samsung\'s youngest J series. It boasts of a powerful processor along with exciting cameras but misses out a good display. And just like most other phablets, it is too heavy. The new Samsung Galaxy J7 2016 a powerful and elegant smartphone with its excellent design and good features.'},
{'id': 'GalaxyJ5', 'text': 'The Samsung Galaxy J5 2015 is an extension of the company\'s youngest J series of smartphones. This mid range device doesn\'t have anything surprising but also doesn\'t miss out anything that you should expect for its price. The excellent pair of cameras will surely win the hearts of photo crazy youngsters. On the downside, Samsung hasn\'t taken any efforts to make it look appealing. Click the new edition Samsung Galaxy J5 2016 comes with more power and better features.'},
{'id': 'GalaxyOn7Prime', 'text': 'The Samsung Galaxy On7 Prime 64GB is a premium smartphone which comes with a lot of strong features. It performs well while handling multitasking and offers a massive storage to enhance your entertainment scope. You can capture high-resolution images and record Full-HD videos with the excellent pair of cameras. Overall, if you are looking for a powerful mid-range device then you can go for the Samsung Galaxy On7 Prime 64GB.'},
{'id': 'GalaxyJ2Pro', 'text': 'The Samsung Galaxy J2 Pro is the latest mid range device from the South Korean tech giant. The device is a combination of good looks and powerful performance. The handset also comes with many innovative features like Turbo Speed Technology,  Smart Glow ring as well as Samsung\'s popular ultra data saving and S bike mode.'},
{'id': 'GalaxyS7Edge', 'text': 'The Samsung Galaxy S7 Edge is a monster in terms of specs and features and with 3D glass and metal body it combines beauty too. Additional features such as dust and waterproof make it a perfect choice. Along with Samsung Galaxy S7, it boasts of being the first phones to come with dual pixel camera as well.'},
{'id': 'OnePlus5', 'text': 'OnePlus, the Chinese smartphone maker has taken the league of smartphones to an altogether different level. The OnePlus 5 holds one of the most powerful processors and camera in the segment. Apart from this, the smart connectivity features, big battery backup and high internal storage leaves nothing to complain about, even with the high price tag.'},
{'id': 'OnePlus5T', 'text': 'The OnePlus 5T is an amazing smartphone and ticks all the correct boxes. All of the features, including the high-performance processor, an amazing pair of cameras, massive internal storage and a sharp display, work in tandem to make this smartphone work in a beast mode each time you use it. Almost every section of the smartphone is lag-free and delivers superior quality of everything. Moreover, a device with such calibre is seldom seen at that price tag.'},
{'id': 'GalaxyS9', 'text': 'The Samsung Galaxy S9 is a power packed smartphone with nice features such as a waterproof body and quick charging support. It comes in a stylish body and is a sound performer. The display quality, cameras and battery backup are great. The Samsung Galaxy S9 is worth buying. It has all the elements which the user desires from a top brand.'},
{'id': 'HTCU11', 'text': 'The HTC 11 is another powerful smartphone front the house of HTC, which has been extremely generous in providing the Indian smartphone market with a large number of great quality smartphones. This smartphone feeds from a powerful processor and a great camera quality. So if you want to own such a smartphone, there wouldn�t have been any better option than this.'},
{'id': 'HTCDesire10', 'text': 'The HTC Desire 10 Pro is a robust configured handset and marvellous cameras. The ample expandable memory is ideal for the ones looking out to save large number of high sized files. The users can enjoy 4G connectivity for long hours since the battery backup is excellent. However, a front flash would have been a good thing.'},
{'id': 'HTCU', 'text': 'The HTC U Play is another powerful smartphone fromt the house of HTC, which has been extremely generous in providing the Indian smartphone market with a large number of great quality smartphones. This smartphone feeds from an extremely powerful processor and a great camera quality, apart from offering a humongous storage option. So if you want to own such a smartphone, there wouldn�t be any better option than this.'},
{'id': 'HTC10Lifestyle', 'text': 'The semi-transparent front view metallic frame of the HTC 10 LifeStyle makes it one of the gorgeous looking smartphones in India. It is equipped with all the latest features and good specification one expects from a phone in this price segment. If you are looking for an all rounder phone that can also handle the bumps and slips of everyday life, the HTC 10 LifeStyle is a good option.'},
{'id': 'HTCDesire630', 'text': 'The HTC Desire 630 is basically for the ones who are looking forward to buy a GSM + CDMA phone along with nice cameras. Latest operating system comes as an additional package. However, a better battery along with an octa-core processor would have make it a perfect device..'},
{'id': 'RedmiNote5', 'text': 'The Xiaomi Redmi Note 5 is a promising smartphone with impressive features in all the departments. Despite having an affordable price tag, the phone carries a lot of features which are exclusive only to high-end smartphones according to the current market trend.'},
{'id': 'RedmitNote4', 'text': 'The Xiaomi Redmi Note 4 64GB brings more uniform metal texture, different from the previous \'three-stage\' metal Redmi series body. The independent space system is like having an additional cell phone. The users can play high end games and enjoy multitasking apps without any lag. In short, the Redmi Note 4 is one of the perfect allrounder handset for you.'},
{'id': 'Nokia8', 'text': 'The Nokia 8 is another addition to the Nokia series with class performance. It is very evident that the Nokia company is looking forward to introduce back to back mobiles this year. On a concluding note, the Nokia 8 is clearly a winner in all aspects and is a very profitable choice. An impressive display, a good battery backup with quick-charging, great configuration and excellent cameras completely makes this phone worthy.'},
]}

# %%
headers   = {"Ocp-Apim-Subscription-Key": subscription_key}
response  = requests.post(key_phrase_api_url, headers=headers, json=documents)
key_phrases = response.json()
pprint(key_phrases)
# Out:
# {'documents': [{'id': 'iphoneX',
#                 'keyPhrases': ['Apple iPhone X',
#                                'new iPhone',
#                                'home button',
#                                'fingerprint scanner',
#                                'FaceID',
#                                'groundbreaking launches',
#                                'technology',
#                                'big time',
#                                'design',
#                                'department']},
#                {'id': 'LGG6',
#                 'keyPhrases': ['powerful flagship smartphone',
#                                'smartphone feeds',
#                                'Indian smartphone market',
#                                'large number of great quality flagship '
#                                'smartphones',
#                                'great camera quality',
#                                'powerful processor',
#                                'LG G6',
#                                'house of LG',
#                                'wouldn',
#                                'better option']},
#                {'id': 'Iphone8',
#                 'keyPhrases': ['notch',
#                                'norm of manufacturing smartphones',
#                                'best',
#                                'love',
#                                'high-end brand',
#                                'configuration',
#                                'battery',
#                                'huge bucks',
#                                'predecessor',
#                                'ways',
#                                'iPhones',
#                                'Apple']},
#                {'id': 'Iphone7',
#                 'keyPhrases': ['larger brain',
#                                'larger battery backup',
#                                'beauty worth',
#                                'wide arrayed connectivity options',
#                                'bag',
#                                'amazing camera',
#                                'flagship',
#                                'patented features',
#                                'latest iOS',
#                                'smartphone',
#                                'powerful processor',
#                                'good buy',
#                                'Apple iPhone',
#                                'tasks']},
#                {'id': 'IphoneSE',
#                 'keyPhrases': ['series smartphones',
#                                'previous iPhone',
#                                'iPhone SE',
#                                "Apple's newiPhone",
#                                'smaller version',
#                                'upgraded features',
#                                'goodness',
#                                'users',
#                                'attention']},
#                {'id': 'Iphone6s',
#                 'keyPhrases': ['iPhone SE',
#                                'previous iPhone',
#                                'premium phone',
#                                'premium price tag',
#                                'series smartphones',
#                                'flagship device',
#                                'bag',
#                                'patented features',
#                                'wide arrayed connectivity',
#                                'decent performing configuration',
#                                'good buy']},
#                {'id': 'Pixel2',
#                 'keyPhrases': ['powerful device',
#                                'users',
#                                'Google',
#                                'little features',
#                                'latest version of Android OS',
#                                'good pair of cameras',
#                                'Pixel XL',
#                                'high price',
#                                'excellent display properties',
#                                'success',
#                                'Nexus series',
#                                'bang',
#                                'craze',
#                                'love',
#                                'check']},
#                {'id': 'Pixel',
#                 'keyPhrases': ['Pixel series',
#                                'good pair of cameras',
#                                'Pixel XL',
#                                'powerful device',
#                                'Nexus series',
#                                'craze',
#                                'Google',
#                                'little features',
#                                'latest version of Android OS',
#                                'high price',
#                                'obvious option',
#                                'success',
#                                'bang',
#                                'performance',
#                                'check']},
#                {'id': 'GalaxyS8',
#                 'keyPhrases': ['new flagship phone',
#                                'korean tech giant',
#                                'Samsung Galaxy S8',
#                                'specification',
#                                'demand',
#                                'budget',
#                                'best features',
#                                'splendid smartphone',
#                                'barrier',
#                                'consumers',
#                                'release']},
#                {'id': 'GalaxyNote8',
#                 'keyPhrases': ['best smartphone',
#                                'sound performance',
#                                'curved display',
#                                'S-Pen',
#                                'wireless charging support',
#                                'great photography capabilities',
#                                'high price tag',
#                                'Samsung Galaxy',
#                                'market']},
#                {'id': 'GalaxyA8+',
#                 'keyPhrases': ['power-packed device',
#                                'great smartphone experience',
#                                'selfie camera',
#                                'powerhouse',
#                                'terms of performance',
#                                'storage',
#                                'cameras',
#                                'major highlight',
#                                'tablet',
#                                'users',
#                                'quick charging feature',
#                                'perfect blend',
#                                'Samsung Galaxy A8',
#                                'battery backup',
#                                'phablet']},
#                {'id': 'GalaxyC9Pro',
#                 'keyPhrases': ['processor',
#                                'battery',
#                                'powerful features',
#                                'Samsung Galaxy C9 Pro',
#                                'great display',
#                                'premium smartphone',
#                                'cameras',
#                                'peers']},
#                {'id': 'GalaxyC7',
#                 'keyPhrases': ['smartphone contenders',
#                                'elegant metal outfit',
#                                'scaled hardware',
#                                'lower pixel density',
#                                'avid photographer',
#                                'midrange flagship',
#                                'Samsung Galaxy C7 Pro',
#                                'trustworthy brand',
#                                'issue',
#                                'selfie fanatic',
#                                'budget',
#                                'Connectivity']},
#                {'id': 'GalaxyJ7',
#                 'keyPhrases': ['new Samsung Galaxy J7',
#                                'powerful processor',
#                                'good features',
#                                'good display',
#                                'elegant smartphone',
#                                'Korean electronics giant',
#                                'excellent design',
#                                "Samsung's youngest J series",
#                                'exciting cameras',
#                                'mid range portfolio',
#                                'phablets']},
#                {'id': 'GalaxyJ5',
#                 'keyPhrases': ['new edition Samsung Galaxy J5',
#                                'extension',
#                                "company's youngest J series of smartphones",
#                                'power',
#                                'hearts of photo crazy youngsters',
#                                'mid range device',
#                                'efforts',
#                                'excellent pair of cameras',
#                                'better features',
#                                'downside',
#                                'price']},
#                {'id': 'GalaxyOn7Prime',
#                 'keyPhrases': ['GB',
#                                'Samsung Galaxy On7 Prime',
#                                'HD videos',
#                                'premium smartphone',
#                                'massive storage',
#                                'excellent pair of cameras',
#                                'powerful mid-range device',
#                                'entertainment scope',
#                                'lot of strong features',
#                                'high-resolution images']},
#                {'id': 'GalaxyJ2Pro',
#                 'keyPhrases': ['latest mid range device',
#                                'Smart Glow ring',
#                                'Turbo Speed Technology',
#                                "Samsung's popular ultra data",
#                                'innovative features',
#                                'Samsung Galaxy J2 Pro',
#                                'South Korean tech giant',
#                                'S bike mode',
#                                'combination of good looks',
#                                'powerful performance',
#                                'handset']},
#                {'id': 'GalaxyS7Edge',
#                 'keyPhrases': ['Samsung Galaxy S7 Edge',
#                                'Additional features',
#                                'monster',
#                                'waterproof',
#                                'D glass',
#                                'terms of specs',
#                                'metal body',
#                                'dust',
#                                'phones',
#                                'dual pixel camera',
#                                'beauty',
#                                'perfect choice']},
#                {'id': 'OnePlus5',
#                 'keyPhrases': ['OnePlus',
#                                'high internal storage leaves',
#                                'high price tag',
#                                'big battery backup',
#                                'smart connectivity features',
#                                'league of smartphones',
#                                'Chinese smartphone maker',
#                                'powerful processors',
#                                'camera',
#                                'segment',
#                                'different level']},
#                {'id': 'OnePlus5T',
#                 'keyPhrases': ['amazing smartphone',
#                                'smartphone work',
#                                'amazing pair of cameras',
#                                'massive internal storage',
#                                'sharp display',
#                                'tandem',
#                                'high-performance processor',
#                                'beast mode',
#                                'time',
#                                'OnePlus',
#                                'correct boxes',
#                                'calibre',
#                                'superior quality',
#                                'features',
#                                'price tag',
#                                'device',
#                                'section']},
#                {'id': 'GalaxyS9',
#                 'keyPhrases': ['Samsung Galaxy S9',
#                                'waterproof body',
#                                'stylish body',
#                                'power packed smartphone',
#                                'nice features',
#                                'cameras',
#                                'battery backup',
#                                'display quality',
#                                'quick charging support',
#                                'user desires',
#                                'sound performer',
#                                'elements',
#                                'brand']},
#                {'id': 'HTCU11',
#                 'keyPhrases': ['powerful smartphone',
#                                'smartphone feeds',
#                                'Indian smartphone market',
#                                'great camera quality',
#                                'powerful processor',
#                                'large number of great quality smartphones',
#                                'house of HTC',
#                                'wouldn',
#                                'better option']},
#                {'id': 'HTCDesire10',
#                 'keyPhrases': ['robust configured handset',
#                                'long hours',
#                                'ones',
#                                'Pro',
#                                'G connectivity',
#                                'battery backup',
#                                'large number of high sized files',
#                                'marvellous cameras',
#                                'ample expandable memory',
#                                'HTC Desire',
#                                'flash',
#                                'good thing',
#                                'users']},
#                {'id': 'HTCU',
#                 'keyPhrases': ['smartphone feeds',
#                                'powerful smartphone fromt',
#                                'Indian smartphone market',
#                                'great camera quality',
#                                'powerful processor',
#                                'house of HTC',
#                                'large number of great quality smartphones',
#                                'better option',
#                                'HTC U Play',
#                                'humongous storage option',
#                                'wouldn']},
#                {'id': 'HTC10Lifestyle',
#                 'keyPhrases': ['HTC',
#                                'LifeStyle',
#                                'good specification',
#                                'good option',
#                                'rounder phone',
#                                'gorgeous looking smartphones',
#                                'view metallic frame',
#                                'slips of everyday life',
#                                'bumps',
#                                'India',
#                                'latest features',
#                                'price segment']},
#                {'id': 'HTCDesire630',
#                 'keyPhrases': ['CDMA phone',
#                                'nice cameras',
#                                'octa-core processor',
#                                'GSM',
#                                'better battery',
#                                'additional package',
#                                'HTC Desire',
#                                'perfect device',
#                                'ones']},
#                {'id': 'RedmiNote5',
#                 'keyPhrases': ['impressive features',
#                                'lot of features',
#                                'high-end smartphones',
#                                'promising smartphone',
#                                'current market trend',
#                                'affordable price tag',
#                                'Xiaomi Redmi',
#                                'departments']},
#                {'id': 'RedmitNote4',
#                 'keyPhrases': ['Xiaomi Redmi',
#                                'metal Redmi series body',
#                                'uniform metal texture',
#                                'multitasking apps',
#                                'high end games',
#                                'GB',
#                                'stage',
#                                'independent space system',
#                                'additional cell phone',
#                                'users',
#                                'perfect allrounder handset',
#                                'lag']},
#                {'id': 'Nokia8',
#                 'keyPhrases': ['Nokia series',
#                                'Nokia company',
#                                'quick-charging',
#                                'good battery backup',
#                                'excellent cameras',
#                                'great configuration',
#                                'impressive display',
#                                'addition',
#                                'class performance',
#                                'aspects',
#                                'phone worthy',
#                                'profitable choice',
#                                'concluding note',
#                                'winner',
#                                'mobiles',
#                                'year']}],
#  'errors': []}

# %%
P =""
for document in key_phrases["documents"]:
    text    = next(filter(lambda d: d["id"] == document["id"], documents["documents"]))["text"]    
    phrases = ",".join(document["keyPhrases"])
    P = P+phrases

# %%
P
# Out:
# "Apple iPhone X,new iPhone,home button,fingerprint scanner,FaceID,groundbreaking launches,technology,big time,design,departmentpowerful flagship smartphone,smartphone feeds,Indian smartphone market,large number of great quality flagship smartphones,great camera quality,powerful processor,LG G6,house of LG,wouldn,better optionnotch,norm of manufacturing smartphones,best,love,high-end brand,configuration,battery,huge bucks,predecessor,ways,iPhones,Applelarger brain,larger battery backup,beauty worth,wide arrayed connectivity options,bag,amazing camera,flagship,patented features,latest iOS,smartphone,powerful processor,good buy,Apple iPhone,tasksseries smartphones,previous iPhone,iPhone SE,Apple's newiPhone,smaller version,upgraded features,goodness,users,attentioniPhone SE,previous iPhone,premium phone,premium price tag,series smartphones,flagship device,bag,patented features,wide arrayed connectivity,decent performing configuration,good buypowerful device,users,Google,little features,latest version of Android OS,good pair of cameras,Pixel XL,high price,excellent display properties,success,Nexus series,bang,craze,love,checkPixel series,good pair of cameras,Pixel XL,powerful device,Nexus series,craze,Google,little features,latest version of Android OS,high price,obvious option,success,bang,performance,checknew flagship phone,korean tech giant,Samsung Galaxy S8,specification,demand,budget,best features,splendid smartphone,barrier,consumers,releasebest smartphone,sound performance,curved display,S-Pen,wireless charging support,great photography capabilities,high price tag,Samsung Galaxy,marketpower-packed device,great smartphone experience,selfie camera,powerhouse,terms of performance,storage,cameras,major highlight,tablet,users,quick charging feature,perfect blend,Samsung Galaxy A8,battery backup,phabletprocessor,battery,powerful features,Samsung Galaxy C9 Pro,great display,premium smartphone,cameras,peerssmartphone contenders,elegant metal outfit,scaled hardware,lower pixel density,avid photographer,midrange flagship,Samsung Galaxy C7 Pro,trustworthy brand,issue,selfie fanatic,budget,Connectivitynew Samsung Galaxy J7,powerful processor,good features,good display,elegant smartphone,Korean electronics giant,excellent design,Samsung's youngest J series,exciting cameras,mid range portfolio,phabletsnew edition Samsung Galaxy J5,extension,company's youngest J series of smartphones,power,hearts of photo crazy youngsters,mid range device,efforts,excellent pair of cameras,better features,downside,priceGB,Samsung Galaxy On7 Prime,HD videos,premium smartphone,massive storage,excellent pair of cameras,powerful mid-range device,entertainment scope,lot of strong features,high-resolution imageslatest mid range device,Smart Glow ring,Turbo Speed Technology,Samsung's popular ultra data,innovative features,Samsung Galaxy J2 Pro,South Korean tech giant,S bike mode,combination of good looks,powerful performance,handsetSamsung Galaxy S7 Edge,Additional features,monster,waterproof,D glass,terms of specs,metal body,dust,phones,dual pixel camera,beauty,perfect choiceOnePlus,high internal storage leaves,high price tag,big battery backup,smart connectivity features,league of smartphones,Chinese smartphone maker,powerful processors,camera,segment,different levelamazing smartphone,smartphone work,amazing pair of cameras,massive internal storage,sharp display,tandem,high-performance processor,beast mode,time,OnePlus,correct boxes,calibre,superior quality,features,price tag,device,sectionSamsung Galaxy S9,waterproof body,stylish body,power packed smartphone,nice features,cameras,battery backup,display quality,quick charging support,user desires,sound performer,elements,brandpowerful smartphone,smartphone feeds,Indian smartphone market,great camera quality,powerful processor,large number of great quality smartphones,house of HTC,wouldn,better optionrobust configured handset,long hours,ones,Pro,G connectivity,battery backup,large number of high sized files,marv ...

# %%
import pandas as pd
pd.options.mode.chained_assignment = None 
import numpy as np
import re
import nltk

from gensim.models import word2vec

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_csv('train.csv').sample(50000, random_state=23)

# %%
STOP_WORDS = nltk.corpus.stopwords.words()
def clean_sentence(val):
    "remove chars that are not letters or numbers, downcase, then remove stop words"
    regex = re.compile('([^\s\w]|_)+')
    sentence = regex.sub('', val).lower()
    sentence = sentence.split(" ")
    
    for word in list(sentence):
        if word in STOP_WORDS:
            sentence.remove(word)  
            
    sentence = " ".join(sentence)
    return sentence

def clean_dataframe(data):
    "drop nans, then apply 'clean_sentence' function to question1 and 2"
    data = data.dropna(how="any")
    
    for col in ['question1', 'question2']:
        data[col] = data[col].apply(clean_sentence)
    
    return data

data = clean_dataframe(data)
data.head(5)
# Out:
#             id    qid1    qid2  \
# 237921  237921    9732   79801
# 181001  181001  277377  277378
# 294691  294691  150129   93109
# 104145  104145  171986  171987
# 357893  357893  487310  487311
#
#                                                 question1  \
# 237921                         sex necessary relationship
# 181001                            inspiring start stories
# 294691                         best way digital marketing
# 104145                    best way grow facebook fan page
# 357893  suppose host sends two tcp segments back back ...
#
#                                                 question2  is_duplicate
# 237921                    sex important good relationship             1
# 181001                         inspirational stories ever             0
# 294691                 best unique ways digital marketing             1
# 104145                        get followers facebook page             1
# 357893  suppose host sends two tcp segments back back ...             1

# %%
t = int(len(P)/100)

# %%
d =int(t)*[[]]

# %%
import nltk

w=0
q=0
for i in nltk.word_tokenize(P):
    
    if i not in STOP_WORDS and i!=',':
            d[w].append(i)
            q+=1
    if q>=100:
        q= 0
        w+=1
    
d
# Out:
# [['Apple',
#   'iPhone',
#   'X',
#   'new',
#   'iPhone',
#   'home',
#   'button',
#   'fingerprint',
#   'scanner',
#   'FaceID',
#   'groundbreaking',
#   'launches',
#   'technology',
#   'big',
#   'time',
#   'design',
#   'departmentpowerful',
#   'flagship',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'flagship',
#   'smartphones',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'LG',
#   'G6',
#   'house',
#   'LG',
#   'better',
#   'optionnotch',
#   'norm',
#   'manufacturing',
#   'smartphones',
#   'best',
#   'love',
#   'high-end',
#   'brand',
#   'configuration',
#   'battery',
#   'huge',
#   'bucks',
#   'predecessor',
#   'ways',
#   'iPhones',
#   'Applelarger',
#   'brain',
#   'larger',
#   'battery',
#   'backup',
#   'beauty',
#   'worth',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'options',
#   'bag',
#   'amazing',
#   'camera',
#   'flagship',
#   'patented',
#   'features',
#   'latest',
#   'iOS',
#   'smartphone',
#   'powerful',
#   'processor',
#   'good',
#   'buy',
#   'Apple',
#   'iPhone',
#   'tasksseries',
#   'smartphones',
#   'previous',
#   'iPhone',
#   'iPhone',
#   'SE',
#   'Apple',
#   "'s",
#   'newiPhone',
#   'smaller',
#   'version',
#   'upgraded',
#   'features',
#   'goodness',
#   'users',
#   'attentioniPhone',
#   'SE',
#   'previous',
#   'iPhone',
#   'premium',
#   'phone',
#   'premium',
#   'price',
#   'tag',
#   'series',
#   'smartphones',
#   'flagship',
#   'device',
#   'bag',
#   'patented',
#   'features',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'decent',
#   'performing',
#   'configuration',
#   'good',
#   'buypowerful',
#   'device',
#   'users',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'high',
#   'price',
#   'excellent',
#   'display',
#   'properties',
#   'success',
#   'Nexus',
#   'series',
#   'bang',
#   'craze',
#   'love',
#   'checkPixel',
#   'series',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'powerful',
#   'device',
#   'Nexus',
#   'series',
#   'craze',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'high',
#   'price',
#   'obvious',
#   'option',
#   'success',
#   'bang',
#   'performance',
#   'checknew',
#   'flagship',
#   'phone',
#   'korean',
#   'tech',
#   'giant',
#   'Samsung',
#   'Galaxy',
#   'S8',
#   'specification',
#   'demand',
#   'budget',
#   'best',
#   'features',
#   'splendid',
#   'smartphone',
#   'barrier',
#   'consumers',
#   'releasebest',
#   'smartphone',
#   'sound',
#   'performance',
#   'curved',
#   'display',
#   'S-Pen',
#   'wireless',
#   'charging',
#   'support',
#   'great',
#   'photography',
#   'capabilities',
#   'high',
#   'price',
#   'tag',
#   'Samsung',
#   'Galaxy',
#   'marketpower-packed',
#   'device',
#   'great',
#   'smartphone',
#   'experience',
#   'selfie',
#   'camera',
#   'powerhouse',
#   'terms',
#   'performance',
#   'storage',
#   'cameras',
#   'major',
#   'highlight',
#   'tablet',
#   'users',
#   'quick',
#   'charging',
#   'feature',
#   'perfect',
#   'blend',
#   'Samsung',
#   'Galaxy',
#   'A8',
#   'battery',
#   'backup',
#   'phabletprocessor',
#   'battery',
#   'powerful',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'C9',
#   'Pro',
#   'great',
#   'display',
#   'premium',
#   'smartphone',
#   'cameras',
#   'peerssmartphone',
#   'contenders',
#   'elegant',
#   'metal',
#   'outfit',
#   'scaled',
#   'hardware',
#   'lower',
#   'pixel',
#   'density',
#   'avid',
#   'photographer',
#   'midrange',
#   'flagship',
#   'Samsung',
#   'Galaxy',
#   'C7',
#   'Pro',
#   'trustworthy',
#   'brand',
#   'issue',
#   'selfie',
#   'fanatic',
#   'budget',
#   'Connectivitynew',
#   'Samsung',
#   'Galaxy',
#   'J7',
#   'powerful',
#   'processor',
#   'good',
#   'features',
#   'good',
#   'display',
#   'elegant',
#   'smartphone',
#   'Korean',
#   'electronics',
#   'giant',
#   'excellent',
#   'design',
#   'Samsung',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'exciting',
#   'cameras',
#   'mid',
#   'range',
#   'portfolio',
#   'phabletsnew',
#   'edition',
#   'Samsung',
#   'Galaxy',
#   'J5',
#   'extension',
#   'company',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'smartphones',
#   'power',
#   'hearts',
#   'photo',
#   'crazy',
#   'youngsters',
#   'mid',
#   'range',
#   'device',
#   'efforts',
#   'excellent',
#   'pair',
#   'cameras',
#   'better',
#   'features',
#   'downside',
#   'priceGB',
#   'Samsung',
#   'Galaxy',
#   'On7',
#   'Prime',
#   'HD',
#   'videos',
#   'premium',
#   'smartphone',
#   'massive',
#   'storage',
#   'excellent',
#   'pair',
#   'cameras',
#   'powerful',
#   'mid-range',
#   'device',
#   'entertainment',
#   'scope',
#   'lot',
#   'strong',
#   'features',
#   'high-resolution',
#   'imageslatest',
#   'mid',
#   'range',
#   'device',
#   'Smart',
#   'Glow',
#   'ring',
#   'Turbo',
#   'Speed',
#   'Technology',
#   'Samsung',
#   "'s",
#   'popular',
#   'ultra',
#   'data',
#   'innovative',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'J2',
#   'Pro',
#   'South',
#   'Korean',
#   'tech',
#   'giant',
#   'S',
#   'bike',
#   'mode',
#   'combination',
#   'good',
#   'looks',
#   'powerful',
#   'performance',
#   'handsetSamsung',
#   'Galaxy',
#   'S7',
#   'Edge',
#   'Additional',
#   'features',
#   'monster',
#   'waterproof',
#   'D',
#   'glass',
#   'terms',
#   'specs',
#   'metal',
#   'body',
#   'dust',
#   'phones',
#   'dual',
#   'pixel',
#   'camera',
#   'beauty',
#   'perfect',
#   'choiceOnePlus',
#   'high',
#   'internal',
#   'storage',
#   'leaves',
#   'high',
#   'price',
#   'tag',
#   'big',
#   'battery',
#   'backup',
#   'smart',
#   'connectivity',
#   'features',
#   'league',
#   'smartphones',
#   'Chinese',
#   'smartphone',
#   'maker',
#   'powerful',
#   'processors',
#   'camera',
#   'segment',
#   'different',
#   'levelamazing',
#   'smartphone',
#   'smartphone',
#   'work',
#   'amazing',
#   'pair',
#   'cameras',
#   'massive',
#   'internal',
#   'storage',
#   'sharp',
#   'display',
#   'tandem',
#   'high-performance',
#   'processor',
#   'beast',
#   'mode',
#   'time',
#   'OnePlus',
#   'correct',
#   'boxes',
#   'calibre',
#   'superior',
#   'quality',
#   'features',
#   'price',
#   'tag',
#   'device',
#   'sectionSamsung',
#   'Galaxy',
#   'S9',
#   'waterproof',
#   'body',
#   'stylish',
#   'body',
#   'power',
#   'packed',
#   'smartphone',
#   'nice',
#   'features',
#   'cameras',
#   'battery',
#   'backup',
#   'display',
#   'quality',
#   'quick',
#   'charging',
#   'support',
#   'user',
#   'desires',
#   'sound',
#   'performer',
#   'elements',
#   'brandpowerful',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'house',
#   'HTC',
#   'better',
#   'optionrobust',
#   'configured',
#   'handset',
#   'long',
#   'hours',
#   'ones',
#   'Pro',
#   'G',
#   'connectivity',
#   'battery',
#   'backup',
#   'large',
#   'number',
#   'high',
#   'sized',
#   'files',
#   'marvellous',
#   'cameras',
#   'ample',
#   'expandable',
#   'memory',
#   'HTC',
#   'Desire',
#   'flash',
#   'good',
#   'thing',
#   'userssmartphone',
#   'feeds',
#   'powerful',
#   'smartphone',
#   'fromt',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'house',
#   'HTC',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'better',
#   'option',
#   'HTC',
#   'U',
#   'Play',
#   'humongous',
#   'storage',
#   'option',
#   'wouldnHTC',
#   'LifeStyle',
#   'good',
#   'specification',
#   'good',
#   'option',
#   'rounder',
#   'phone',
#   'gorgeous',
#   'looking',
#   'smartphones',
#   'view',
#   'metallic',
#   'frame',
#   'slips',
#   'everyday',
#   'life',
#   'bumps',
#   'India',
#   'latest',
#   'features',
#   'price',
#   'segmentCDMA',
#   'phone',
#   'nice',
#   'cameras',
#   'octa-core',
#   'processor',
#   'GSM',
#   'better',
#   'battery',
#   'additional',
#   'package',
#   'HTC',
#   'Desire',
#   'perfect',
#   'device',
#   'onesimpressive',
#   'features',
#   'lot',
#   'features',
#   'high-end',
#   'smartphones',
#   'promising',
#   'smartphone',
#   'current',
#   'market',
#   'trend',
#   'affordable',
#   'price',
#   'tag',
#   'Xiaomi',
#   'Redmi',
#   'departmentsXiaomi',
#   'Redmi',
#   'metal',
#   'Redmi',
#   'series',
#   'body',
#   'uniform',
#   'metal',
#   'texture',
#   'multitasking',
#   'apps',
#   'high',
#   'games',
#   'GB',
#   'stage',
#   'independent',
#   'space',
#   'system',
#   'additional',
#   'cell',
#   'phone',
#   'users',
#   'perfect',
#   'allrounder',
#   'handset',
#   'lagNokia',
#   'series',
#   'Nokia',
#   'company',
#   'quick-charging',
#   'good',
#   'battery',
#   'backup',
#   'excellent',
#   'cameras',
#   'great',
#   'configuration',
#   'impressive',
#   'display',
#   'addition',
#   'class',
#   'performance',
#   'aspects',
#   'phone',
#   'worthy',
#   'profitable',
#   'choice',
#   'concluding',
#   'note',
#   'winner',
#   'mobiles',
#   'year'],
#  ['Apple',
#   'iPhone',
#   'X',
#   'new',
#   'iPhone',
#   'home',
#   'button',
#   'fingerprint',
#   'scanner',
#   'FaceID',
#   'groundbreaking',
#   'launches',
#   'technology',
#   'big',
#   'time',
#   'design',
#   'departmentpowerful',
#   'flagship',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'flagship',
#   'smartphones',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'LG',
#   'G6',
#   'house',
#   'LG',
#   'better',
#   'optionnotch',
#   'norm',
#   'manufacturing',
#   'smartphones',
#   'best',
#   'love',
#   'high-end',
#   'brand',
#   'configuration',
#   'battery',
#   'huge',
#   'bucks',
#   'predecessor',
#   'ways',
#   'iPhones',
#   'Applelarger',
#   'brain',
#   'larger',
#   'battery',
#   'backup',
#   'beauty',
#   'worth',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'options',
#   'bag',
#   'amazing',
#   'camera',
#   'flagship',
#   'patented',
#   'features',
#   'latest',
#   'iOS',
#   'smartphone',
#   'powerful',
#   'processor',
#   'good',
#   'buy',
#   'Apple',
#   'iPhone',
#   'tasksseries',
#   'smartphones',
#   'previous',
#   'iPhone',
#   'iPhone',
#   'SE',
#   'Apple',
#   "'s",
#   'newiPhone',
#   'smaller',
#   'version',
#   'upgraded',
#   'features',
#   'goodness',
#   'users',
#   'attentioniPhone',
#   'SE',
#   'previous',
#   'iPhone',
#   'premium',
#   'phone',
#   'premium',
#   'price',
#   'tag',
#   'series',
#   'smartphones',
#   'flagship',
#   'device',
#   'bag',
#   'patented',
#   'features',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'decent',
#   'performing',
#   'configuration',
#   'good',
#   'buypowerful',
#   'device',
#   'users',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'high',
#   'price',
#   'excellent',
#   'display',
#   'properties',
#   'success',
#   'Nexus',
#   'series',
#   'bang',
#   'craze',
#   'love',
#   'checkPixel',
#   'series',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'powerful',
#   'device',
#   'Nexus',
#   'series',
#   'craze',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'high',
#   'price',
#   'obvious',
#   'option',
#   'success',
#   'bang',
#   'performance',
#   'checknew',
#   'flagship',
#   'phone',
#   'korean',
#   'tech',
#   'giant',
#   'Samsung',
#   'Galaxy',
#   'S8',
#   'specification',
#   'demand',
#   'budget',
#   'best',
#   'features',
#   'splendid',
#   'smartphone',
#   'barrier',
#   'consumers',
#   'releasebest',
#   'smartphone',
#   'sound',
#   'performance',
#   'curved',
#   'display',
#   'S-Pen',
#   'wireless',
#   'charging',
#   'support',
#   'great',
#   'photography',
#   'capabilities',
#   'high',
#   'price',
#   'tag',
#   'Samsung',
#   'Galaxy',
#   'marketpower-packed',
#   'device',
#   'great',
#   'smartphone',
#   'experience',
#   'selfie',
#   'camera',
#   'powerhouse',
#   'terms',
#   'performance',
#   'storage',
#   'cameras',
#   'major',
#   'highlight',
#   'tablet',
#   'users',
#   'quick',
#   'charging',
#   'feature',
#   'perfect',
#   'blend',
#   'Samsung',
#   'Galaxy',
#   'A8',
#   'battery',
#   'backup',
#   'phabletprocessor',
#   'battery',
#   'powerful',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'C9',
#   'Pro',
#   'great',
#   'display',
#   'premium',
#   'smartphone',
#   'cameras',
#   'peerssmartphone',
#   'contenders',
#   'elegant',
#   'metal',
#   'outfit',
#   'scaled',
#   'hardware',
#   'lower',
#   'pixel',
#   'density',
#   'avid',
#   'photographer',
#   'midrange',
#   'flagship',
#   'Samsung',
#   'Galaxy',
#   'C7',
#   'Pro',
#   'trustworthy',
#   'brand',
#   'issue',
#   'selfie',
#   'fanatic',
#   'budget',
#   'Connectivitynew',
#   'Samsung',
#   'Galaxy',
#   'J7',
#   'powerful',
#   'processor',
#   'good',
#   'features',
#   'good',
#   'display',
#   'elegant',
#   'smartphone',
#   'Korean',
#   'electronics',
#   'giant',
#   'excellent',
#   'design',
#   'Samsung',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'exciting',
#   'cameras',
#   'mid',
#   'range',
#   'portfolio',
#   'phabletsnew',
#   'edition',
#   'Samsung',
#   'Galaxy',
#   'J5',
#   'extension',
#   'company',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'smartphones',
#   'power',
#   'hearts',
#   'photo',
#   'crazy',
#   'youngsters',
#   'mid',
#   'range',
#   'device',
#   'efforts',
#   'excellent',
#   'pair',
#   'cameras',
#   'better',
#   'features',
#   'downside',
#   'priceGB',
#   'Samsung',
#   'Galaxy',
#   'On7',
#   'Prime',
#   'HD',
#   'videos',
#   'premium',
#   'smartphone',
#   'massive',
#   'storage',
#   'excellent',
#   'pair',
#   'cameras',
#   'powerful',
#   'mid-range',
#   'device',
#   'entertainment',
#   'scope',
#   'lot',
#   'strong',
#   'features',
#   'high-resolution',
#   'imageslatest',
#   'mid',
#   'range',
#   'device',
#   'Smart',
#   'Glow',
#   'ring',
#   'Turbo',
#   'Speed',
#   'Technology',
#   'Samsung',
#   "'s",
#   'popular',
#   'ultra',
#   'data',
#   'innovative',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'J2',
#   'Pro',
#   'South',
#   'Korean',
#   'tech',
#   'giant',
#   'S',
#   'bike',
#   'mode',
#   'combination',
#   'good',
#   'looks',
#   'powerful',
#   'performance',
#   'handsetSamsung',
#   'Galaxy',
#   'S7',
#   'Edge',
#   'Additional',
#   'features',
#   'monster',
#   'waterproof',
#   'D',
#   'glass',
#   'terms',
#   'specs',
#   'metal',
#   'body',
#   'dust',
#   'phones',
#   'dual',
#   'pixel',
#   'camera',
#   'beauty',
#   'perfect',
#   'choiceOnePlus',
#   'high',
#   'internal',
#   'storage',
#   'leaves',
#   'high',
#   'price',
#   'tag',
#   'big',
#   'battery',
#   'backup',
#   'smart',
#   'connectivity',
#   'features',
#   'league',
#   'smartphones',
#   'Chinese',
#   'smartphone',
#   'maker',
#   'powerful',
#   'processors',
#   'camera',
#   'segment',
#   'different',
#   'levelamazing',
#   'smartphone',
#   'smartphone',
#   'work',
#   'amazing',
#   'pair',
#   'cameras',
#   'massive',
#   'internal',
#   'storage',
#   'sharp',
#   'display',
#   'tandem',
#   'high-performance',
#   'processor',
#   'beast',
#   'mode',
#   'time',
#   'OnePlus',
#   'correct',
#   'boxes',
#   'calibre',
#   'superior',
#   'quality',
#   'features',
#   'price',
#   'tag',
#   'device',
#   'sectionSamsung',
#   'Galaxy',
#   'S9',
#   'waterproof',
#   'body',
#   'stylish',
#   'body',
#   'power',
#   'packed',
#   'smartphone',
#   'nice',
#   'features',
#   'cameras',
#   'battery',
#   'backup',
#   'display',
#   'quality',
#   'quick',
#   'charging',
#   'support',
#   'user',
#   'desires',
#   'sound',
#   'performer',
#   'elements',
#   'brandpowerful',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'house',
#   'HTC',
#   'better',
#   'optionrobust',
#   'configured',
#   'handset',
#   'long',
#   'hours',
#   'ones',
#   'Pro',
#   'G',
#   'connectivity',
#   'battery',
#   'backup',
#   'large',
#   'number',
#   'high',
#   'sized',
#   'files',
#   'marvellous',
#   'cameras',
#   'ample',
#   'expandable',
#   'memory',
#   'HTC',
#   'Desire',
#   'flash',
#   'good',
#   'thing',
#   'userssmartphone',
#   'feeds',
#   'powerful',
#   'smartphone',
#   'fromt',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'house',
#   'HTC',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'better',
#   'option',
#   'HTC',
#   'U',
#   'Play',
#   'humongous',
#   'storage',
#   'option',
#   'wouldnHTC',
#   'LifeStyle',
#   'good',
#   'specification',
#   'good',
#   'option',
#   'rounder',
#   'phone',
#   'gorgeous',
#   'looking',
#   'smartphones',
#   'view',
#   'metallic',
#   'frame',
#   'slips',
#   'everyday',
#   'life',
#   'bumps',
#   'India',
#   'latest',
#   'features',
#   'price',
#   'segmentCDMA',
#   'phone',
#   'nice',
#   'cameras',
#   'octa-core',
#   'processor',
#   'GSM',
#   'better',
#   'battery',
#   'additional',
#   'package',
#   'HTC',
#   'Desire',
#   'perfect',
#   'device',
#   'onesimpressive',
#   'features',
#   'lot',
#   'features',
#   'high-end',
#   'smartphones',
#   'promising',
#   'smartphone',
#   'current',
#   'market',
#   'trend',
#   'affordable',
#   'price',
#   'tag',
#   'Xiaomi',
#   'Redmi',
#   'departmentsXiaomi',
#   'Redmi',
#   'metal',
#   'Redmi',
#   'series',
#   'body',
#   'uniform',
#   'metal',
#   'texture',
#   'multitasking',
#   'apps',
#   'high',
#   'games',
#   'GB',
#   'stage',
#   'independent',
#   'space',
#   'system',
#   'additional',
#   'cell',
#   'phone',
#   'users',
#   'perfect',
#   'allrounder',
#   'handset',
#   'lagNokia',
#   'series',
#   'Nokia',
#   'company',
#   'quick-charging',
#   'good',
#   'battery',
#   'backup',
#   'excellent',
#   'cameras',
#   'great',
#   'configuration',
#   'impressive',
#   'display',
#   'addition',
#   'class',
#   'performance',
#   'aspects',
#   'phone',
#   'worthy',
#   'profitable',
#   'choice',
#   'concluding',
#   'note',
#   'winner',
#   'mobiles',
#   'year'],
#  ['Apple',
#   'iPhone',
#   'X',
#   'new',
#   'iPhone',
#   'home',
#   'button',
#   'fingerprint',
#   'scanner',
#   'FaceID',
#   'groundbreaking',
#   'launches',
#   'technology',
#   'big',
#   'time',
#   'design',
#   'departmentpowerful',
#   'flagship',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'flagship',
#   'smartphones',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'LG',
#   'G6',
#   'house',
#   'LG',
#   'better',
#   'optionnotch',
#   'norm',
#   'manufacturing',
#   'smartphones',
#   'best',
#   'love',
#   'high-end',
#   'brand',
#   'configuration',
#   'battery',
#   'huge',
#   'bucks',
#   'predecessor',
#   'ways',
#   'iPhones',
#   'Applelarger',
#   'brain',
#   'larger',
#   'battery',
#   'backup',
#   'beauty',
#   'worth',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'options',
#   'bag',
#   'amazing',
#   'camera',
#   'flagship',
#   'patented',
#   'features',
#   'latest',
#   'iOS',
#   'smartphone',
#   'powerful',
#   'processor',
#   'good',
#   'buy',
#   'Apple',
#   'iPhone',
#   'tasksseries',
#   'smartphones',
#   'previous',
#   'iPhone',
#   'iPhone',
#   'SE',
#   'Apple',
#   "'s",
#   'newiPhone',
#   'smaller',
#   'version',
#   'upgraded',
#   'features',
#   'goodness',
#   'users',
#   'attentioniPhone',
#   'SE',
#   'previous',
#   'iPhone',
#   'premium',
#   'phone',
#   'premium',
#   'price',
#   'tag',
#   'series',
#   'smartphones',
#   'flagship',
#   'device',
#   'bag',
#   'patented',
#   'features',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'decent',
#   'performing',
#   'configuration',
#   'good',
#   'buypowerful',
#   'device',
#   'users',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'high',
#   'price',
#   'excellent',
#   'display',
#   'properties',
#   'success',
#   'Nexus',
#   'series',
#   'bang',
#   'craze',
#   'love',
#   'checkPixel',
#   'series',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'powerful',
#   'device',
#   'Nexus',
#   'series',
#   'craze',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'high',
#   'price',
#   'obvious',
#   'option',
#   'success',
#   'bang',
#   'performance',
#   'checknew',
#   'flagship',
#   'phone',
#   'korean',
#   'tech',
#   'giant',
#   'Samsung',
#   'Galaxy',
#   'S8',
#   'specification',
#   'demand',
#   'budget',
#   'best',
#   'features',
#   'splendid',
#   'smartphone',
#   'barrier',
#   'consumers',
#   'releasebest',
#   'smartphone',
#   'sound',
#   'performance',
#   'curved',
#   'display',
#   'S-Pen',
#   'wireless',
#   'charging',
#   'support',
#   'great',
#   'photography',
#   'capabilities',
#   'high',
#   'price',
#   'tag',
#   'Samsung',
#   'Galaxy',
#   'marketpower-packed',
#   'device',
#   'great',
#   'smartphone',
#   'experience',
#   'selfie',
#   'camera',
#   'powerhouse',
#   'terms',
#   'performance',
#   'storage',
#   'cameras',
#   'major',
#   'highlight',
#   'tablet',
#   'users',
#   'quick',
#   'charging',
#   'feature',
#   'perfect',
#   'blend',
#   'Samsung',
#   'Galaxy',
#   'A8',
#   'battery',
#   'backup',
#   'phabletprocessor',
#   'battery',
#   'powerful',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'C9',
#   'Pro',
#   'great',
#   'display',
#   'premium',
#   'smartphone',
#   'cameras',
#   'peerssmartphone',
#   'contenders',
#   'elegant',
#   'metal',
#   'outfit',
#   'scaled',
#   'hardware',
#   'lower',
#   'pixel',
#   'density',
#   'avid',
#   'photographer',
#   'midrange',
#   'flagship',
#   'Samsung',
#   'Galaxy',
#   'C7',
#   'Pro',
#   'trustworthy',
#   'brand',
#   'issue',
#   'selfie',
#   'fanatic',
#   'budget',
#   'Connectivitynew',
#   'Samsung',
#   'Galaxy',
#   'J7',
#   'powerful',
#   'processor',
#   'good',
#   'features',
#   'good',
#   'display',
#   'elegant',
#   'smartphone',
#   'Korean',
#   'electronics',
#   'giant',
#   'excellent',
#   'design',
#   'Samsung',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'exciting',
#   'cameras',
#   'mid',
#   'range',
#   'portfolio',
#   'phabletsnew',
#   'edition',
#   'Samsung',
#   'Galaxy',
#   'J5',
#   'extension',
#   'company',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'smartphones',
#   'power',
#   'hearts',
#   'photo',
#   'crazy',
#   'youngsters',
#   'mid',
#   'range',
#   'device',
#   'efforts',
#   'excellent',
#   'pair',
#   'cameras',
#   'better',
#   'features',
#   'downside',
#   'priceGB',
#   'Samsung',
#   'Galaxy',
#   'On7',
#   'Prime',
#   'HD',
#   'videos',
#   'premium',
#   'smartphone',
#   'massive',
#   'storage',
#   'excellent',
#   'pair',
#   'cameras',
#   'powerful',
#   'mid-range',
#   'device',
#   'entertainment',
#   'scope',
#   'lot',
#   'strong',
#   'features',
#   'high-resolution',
#   'imageslatest',
#   'mid',
#   'range',
#   'device',
#   'Smart',
#   'Glow',
#   'ring',
#   'Turbo',
#   'Speed',
#   'Technology',
#   'Samsung',
#   "'s",
#   'popular',
#   'ultra',
#   'data',
#   'innovative',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'J2',
#   'Pro',
#   'South',
#   'Korean',
#   'tech',
#   'giant',
#   'S',
#   'bike',
#   'mode',
#   'combination',
#   'good',
#   'looks',
#   'powerful',
#   'performance',
#   'handsetSamsung',
#   'Galaxy',
#   'S7',
#   'Edge',
#   'Additional',
#   'features',
#   'monster',
#   'waterproof',
#   'D',
#   'glass',
#   'terms',
#   'specs',
#   'metal',
#   'body',
#   'dust',
#   'phones',
#   'dual',
#   'pixel',
#   'camera',
#   'beauty',
#   'perfect',
#   'choiceOnePlus',
#   'high',
#   'internal',
#   'storage',
#   'leaves',
#   'high',
#   'price',
#   'tag',
#   'big',
#   'battery',
#   'backup',
#   'smart',
#   'connectivity',
#   'features',
#   'league',
#   'smartphones',
#   'Chinese',
#   'smartphone',
#   'maker',
#   'powerful',
#   'processors',
#   'camera',
#   'segment',
#   'different',
#   'levelamazing',
#   'smartphone',
#   'smartphone',
#   'work',
#   'amazing',
#   'pair',
#   'cameras',
#   'massive',
#   'internal',
#   'storage',
#   'sharp',
#   'display',
#   'tandem',
#   'high-performance',
#   'processor',
#   'beast',
#   'mode',
#   'time',
#   'OnePlus',
#   'correct',
#   'boxes',
#   'calibre',
#   'superior',
#   'quality',
#   'features',
#   'price',
#   'tag',
#   'device',
#   'sectionSamsung',
#   'Galaxy',
#   'S9',
#   'waterproof',
#   'body',
#   'stylish',
#   'body',
#   'power',
#   'packed',
#   'smartphone',
#   'nice',
#   'features',
#   'cameras',
#   'battery',
#   'backup',
#   'display',
#   'quality',
#   'quick',
#   'charging',
#   'support',
#   'user',
#   'desires',
#   'sound',
#   'performer',
#   'elements',
#   'brandpowerful',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'house',
#   'HTC',
#   'better',
#   'optionrobust',
#   'configured',
#   'handset',
#   'long',
#   'hours',
#   'ones',
#   'Pro',
#   'G',
#   'connectivity',
#   'battery',
#   'backup',
#   'large',
#   'number',
#   'high',
#   'sized',
#   'files',
#   'marvellous',
#   'cameras',
#   'ample',
#   'expandable',
#   'memory',
#   'HTC',
#   'Desire',
#   'flash',
#   'good',
#   'thing',
#   'userssmartphone',
#   'feeds',
#   'powerful',
#   'smartphone',
#   'fromt',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'house',
#   'HTC',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'better',
#   'option',
#   'HTC',
#   'U',
#   'Play',
#   'humongous',
#   'storage',
#   'option',
#   'wouldnHTC',
#   'LifeStyle',
#   'good',
#   'specification',
#   'good',
#   'option',
#   'rounder',
#   'phone',
#   'gorgeous',
#   'looking',
#   'smartphones',
#   'view',
#   'metallic',
#   'frame',
#   'slips',
#   'everyday',
#   'life',
#   'bumps',
#   'India',
#   'latest',
#   'features',
#   'price',
#   'segmentCDMA',
#   'phone',
#   'nice',
#   'cameras',
#   'octa-core',
#   'processor',
#   'GSM',
#   'better',
#   'battery',
#   'additional',
#   'package',
#   'HTC',
#   'Desire',
#   'perfect',
#   'device',
#   'onesimpressive',
#   'features',
#   'lot',
#   'features',
#   'high-end',
#   'smartphones',
#   'promising',
#   'smartphone',
#   'current',
#   'market',
#   'trend',
#   'affordable',
#   'price',
#   'tag',
#   'Xiaomi',
#   'Redmi',
#   'departmentsXiaomi',
#   'Redmi',
#   'metal',
#   'Redmi',
#   'series',
#   'body',
#   'uniform',
#   'metal',
#   'texture',
#   'multitasking',
#   'apps',
#   'high',
#   'games',
#   'GB',
#   'stage',
#   'independent',
#   'space',
#   'system',
#   'additional',
#   'cell',
#   'phone',
#   'users',
#   'perfect',
#   'allrounder',
#   'handset',
#   'lagNokia',
#   'series',
#   'Nokia',
#   'company',
#   'quick-charging',
#   'good',
#   'battery',
#   'backup',
#   'excellent',
#   'cameras',
#   'great',
#   'configuration',
#   'impressive',
#   'display',
#   'addition',
#   'class',
#   'performance',
#   'aspects',
#   'phone',
#   'worthy',
#   'profitable',
#   'choice',
#   'concluding',
#   'note',
#   'winner',
#   'mobiles',
#   'year'],
#  ['Apple',
#   'iPhone',
#   'X',
#   'new',
#   'iPhone',
#   'home',
#   'button',
#   'fingerprint',
#   'scanner',
#   'FaceID',
#   'groundbreaking',
#   'launches',
#   'technology',
#   'big',
#   'time',
#   'design',
#   'departmentpowerful',
#   'flagship',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'flagship',
#   'smartphones',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'LG',
#   'G6',
#   'house',
#   'LG',
#   'better',
#   'optionnotch',
#   'norm',
#   'manufacturing',
#   'smartphones',
#   'best',
#   'love',
#   'high-end',
#   'brand',
#   'configuration',
#   'battery',
#   'huge',
#   'bucks',
#   'predecessor',
#   'ways',
#   'iPhones',
#   'Applelarger',
#   'brain',
#   'larger',
#   'battery',
#   'backup',
#   'beauty',
#   'worth',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'options',
#   'bag',
#   'amazing',
#   'camera',
#   'flagship',
#   'patented',
#   'features',
#   'latest',
#   'iOS',
#   'smartphone',
#   'powerful',
#   'processor',
#   'good',
#   'buy',
#   'Apple',
#   'iPhone',
#   'tasksseries',
#   'smartphones',
#   'previous',
#   'iPhone',
#   'iPhone',
#   'SE',
#   'Apple',
#   "'s",
#   'newiPhone',
#   'smaller',
#   'version',
#   'upgraded',
#   'features',
#   'goodness',
#   'users',
#   'attentioniPhone',
#   'SE',
#   'previous',
#   'iPhone',
#   'premium',
#   'phone',
#   'premium',
#   'price',
#   'tag',
#   'series',
#   'smartphones',
#   'flagship',
#   'device',
#   'bag',
#   'patented',
#   'features',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'decent',
#   'performing',
#   'configuration',
#   'good',
#   'buypowerful',
#   'device',
#   'users',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'high',
#   'price',
#   'excellent',
#   'display',
#   'properties',
#   'success',
#   'Nexus',
#   'series',
#   'bang',
#   'craze',
#   'love',
#   'checkPixel',
#   'series',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'powerful',
#   'device',
#   'Nexus',
#   'series',
#   'craze',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'high',
#   'price',
#   'obvious',
#   'option',
#   'success',
#   'bang',
#   'performance',
#   'checknew',
#   'flagship',
#   'phone',
#   'korean',
#   'tech',
#   'giant',
#   'Samsung',
#   'Galaxy',
#   'S8',
#   'specification',
#   'demand',
#   'budget',
#   'best',
#   'features',
#   'splendid',
#   'smartphone',
#   'barrier',
#   'consumers',
#   'releasebest',
#   'smartphone',
#   'sound',
#   'performance',
#   'curved',
#   'display',
#   'S-Pen',
#   'wireless',
#   'charging',
#   'support',
#   'great',
#   'photography',
#   'capabilities',
#   'high',
#   'price',
#   'tag',
#   'Samsung',
#   'Galaxy',
#   'marketpower-packed',
#   'device',
#   'great',
#   'smartphone',
#   'experience',
#   'selfie',
#   'camera',
#   'powerhouse',
#   'terms',
#   'performance',
#   'storage',
#   'cameras',
#   'major',
#   'highlight',
#   'tablet',
#   'users',
#   'quick',
#   'charging',
#   'feature',
#   'perfect',
#   'blend',
#   'Samsung',
#   'Galaxy',
#   'A8',
#   'battery',
#   'backup',
#   'phabletprocessor',
#   'battery',
#   'powerful',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'C9',
#   'Pro',
#   'great',
#   'display',
#   'premium',
#   'smartphone',
#   'cameras',
#   'peerssmartphone',
#   'contenders',
#   'elegant',
#   'metal',
#   'outfit',
#   'scaled',
#   'hardware',
#   'lower',
#   'pixel',
#   'density',
#   'avid',
#   'photographer',
#   'midrange',
#   'flagship',
#   'Samsung',
#   'Galaxy',
#   'C7',
#   'Pro',
#   'trustworthy',
#   'brand',
#   'issue',
#   'selfie',
#   'fanatic',
#   'budget',
#   'Connectivitynew',
#   'Samsung',
#   'Galaxy',
#   'J7',
#   'powerful',
#   'processor',
#   'good',
#   'features',
#   'good',
#   'display',
#   'elegant',
#   'smartphone',
#   'Korean',
#   'electronics',
#   'giant',
#   'excellent',
#   'design',
#   'Samsung',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'exciting',
#   'cameras',
#   'mid',
#   'range',
#   'portfolio',
#   'phabletsnew',
#   'edition',
#   'Samsung',
#   'Galaxy',
#   'J5',
#   'extension',
#   'company',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'smartphones',
#   'power',
#   'hearts',
#   'photo',
#   'crazy',
#   'youngsters',
#   'mid',
#   'range',
#   'device',
#   'efforts',
#   'excellent',
#   'pair',
#   'cameras',
#   'better',
#   'features',
#   'downside',
#   'priceGB',
#   'Samsung',
#   'Galaxy',
#   'On7',
#   'Prime',
#   'HD',
#   'videos',
#   'premium',
#   'smartphone',
#   'massive',
#   'storage',
#   'excellent',
#   'pair',
#   'cameras',
#   'powerful',
#   'mid-range',
#   'device',
#   'entertainment',
#   'scope',
#   'lot',
#   'strong',
#   'features',
#   'high-resolution',
#   'imageslatest',
#   'mid',
#   'range',
#   'device',
#   'Smart',
#   'Glow',
#   'ring',
#   'Turbo',
#   'Speed',
#   'Technology',
#   'Samsung',
#   "'s",
#   'popular',
#   'ultra',
#   'data',
#   'innovative',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'J2',
#   'Pro',
#   'South',
#   'Korean',
#   'tech',
#   'giant',
#   'S',
#   'bike',
#   'mode',
#   'combination',
#   'good',
#   'looks',
#   'powerful',
#   'performance',
#   'handsetSamsung',
#   'Galaxy',
#   'S7',
#   'Edge',
#   'Additional',
#   'features',
#   'monster',
#   'waterproof',
#   'D',
#   'glass',
#   'terms',
#   'specs',
#   'metal',
#   'body',
#   'dust',
#   'phones',
#   'dual',
#   'pixel',
#   'camera',
#   'beauty',
#   'perfect',
#   'choiceOnePlus',
#   'high',
#   'internal',
#   'storage',
#   'leaves',
#   'high',
#   'price',
#   'tag',
#   'big',
#   'battery',
#   'backup',
#   'smart',
#   'connectivity',
#   'features',
#   'league',
#   'smartphones',
#   'Chinese',
#   'smartphone',
#   'maker',
#   'powerful',
#   'processors',
#   'camera',
#   'segment',
#   'different',
#   'levelamazing',
#   'smartphone',
#   'smartphone',
#   'work',
#   'amazing',
#   'pair',
#   'cameras',
#   'massive',
#   'internal',
#   'storage',
#   'sharp',
#   'display',
#   'tandem',
#   'high-performance',
#   'processor',
#   'beast',
#   'mode',
#   'time',
#   'OnePlus',
#   'correct',
#   'boxes',
#   'calibre',
#   'superior',
#   'quality',
#   'features',
#   'price',
#   'tag',
#   'device',
#   'sectionSamsung',
#   'Galaxy',
#   'S9',
#   'waterproof',
#   'body',
#   'stylish',
#   'body',
#   'power',
#   'packed',
#   'smartphone',
#   'nice',
#   'features',
#   'cameras',
#   'battery',
#   'backup',
#   'display',
#   'quality',
#   'quick',
#   'charging',
#   'support',
#   'user',
#   'desires',
#   'sound',
#   'performer',
#   'elements',
#   'brandpowerful',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'house',
#   'HTC',
#   'better',
#   'optionrobust',
#   'configured',
#   'handset',
#   'long',
#   'hours',
#   'ones',
#   'Pro',
#   'G',
#   'connectivity',
#   'battery',
#   'backup',
#   'large',
#   'number',
#   'high',
#   'sized',
#   'files',
#   'marvellous',
#   'cameras',
#   'ample',
#   'expandable',
#   'memory',
#   'HTC',
#   'Desire',
#   'flash',
#   'good',
#   'thing',
#   'userssmartphone',
#   'feeds',
#   'powerful',
#   'smartphone',
#   'fromt',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'house',
#   'HTC',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'better',
#   'option',
#   'HTC',
#   'U',
#   'Play',
#   'humongous',
#   'storage',
#   'option',
#   'wouldnHTC',
#   'LifeStyle',
#   'good',
#   'specification',
#   'good',
#   'option',
#   'rounder',
#   'phone',
#   'gorgeous',
#   'looking',
#   'smartphones',
#   'view',
#   'metallic',
#   'frame',
#   'slips',
#   'everyday',
#   'life',
#   'bumps',
#   'India',
#   'latest',
#   'features',
#   'price',
#   'segmentCDMA',
#   'phone',
#   'nice',
#   'cameras',
#   'octa-core',
#   'processor',
#   'GSM',
#   'better',
#   'battery',
#   'additional',
#   'package',
#   'HTC',
#   'Desire',
#   'perfect',
#   'device',
#   'onesimpressive',
#   'features',
#   'lot',
#   'features',
#   'high-end',
#   'smartphones',
#   'promising',
#   'smartphone',
#   'current',
#   'market',
#   'trend',
#   'affordable',
#   'price',
#   'tag',
#   'Xiaomi',
#   'Redmi',
#   'departmentsXiaomi',
#   'Redmi',
#   'metal',
#   'Redmi',
#   'series',
#   'body',
#   'uniform',
#   'metal',
#   'texture',
#   'multitasking',
#   'apps',
#   'high',
#   'games',
#   'GB',
#   'stage',
#   'independent',
#   'space',
#   'system',
#   'additional',
#   'cell',
#   'phone',
#   'users',
#   'perfect',
#   'allrounder',
#   'handset',
#   'lagNokia',
#   'series',
#   'Nokia',
#   'company',
#   'quick-charging',
#   'good',
#   'battery',
#   'backup',
#   'excellent',
#   'cameras',
#   'great',
#   'configuration',
#   'impressive',
#   'display',
#   'addition',
#   'class',
#   'performance',
#   'aspects',
#   'phone',
#   'worthy',
#   'profitable',
#   'choice',
#   'concluding',
#   'note',
#   'winner',
#   'mobiles',
#   'year'],
#  ['Apple',
#   'iPhone',
#   'X',
#   'new',
#   'iPhone',
#   'home',
#   'button',
#   'fingerprint',
#   'scanner',
#   'FaceID',
#   'groundbreaking',
#   'launches',
#   'technology',
#   'big',
#   'time',
#   'design',
#   'departmentpowerful',
#   'flagship',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'flagship',
#   'smartphones',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'LG',
#   'G6',
#   'house',
#   'LG',
#   'better',
#   'optionnotch',
#   'norm',
#   'manufacturing',
#   'smartphones',
#   'best',
#   'love',
#   'high-end',
#   'brand',
#   'configuration',
#   'battery',
#   'huge',
#   'bucks',
#   'predecessor',
#   'ways',
#   'iPhones',
#   'Applelarger',
#   'brain',
#   'larger',
#   'battery',
#   'backup',
#   'beauty',
#   'worth',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'options',
#   'bag',
#   'amazing',
#   'camera',
#   'flagship',
#   'patented',
#   'features',
#   'latest',
#   'iOS',
#   'smartphone',
#   'powerful',
#   'processor',
#   'good',
#   'buy',
#   'Apple',
#   'iPhone',
#   'tasksseries',
#   'smartphones',
#   'previous',
#   'iPhone',
#   'iPhone',
#   'SE',
#   'Apple',
#   "'s",
#   'newiPhone',
#   'smaller',
#   'version',
#   'upgraded',
#   'features',
#   'goodness',
#   'users',
#   'attentioniPhone',
#   'SE',
#   'previous',
#   'iPhone',
#   'premium',
#   'phone',
#   'premium',
#   'price',
#   'tag',
#   'series',
#   'smartphones',
#   'flagship',
#   'device',
#   'bag',
#   'patented',
#   'features',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'decent',
#   'performing',
#   'configuration',
#   'good',
#   'buypowerful',
#   'device',
#   'users',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'high',
#   'price',
#   'excellent',
#   'display',
#   'properties',
#   'success',
#   'Nexus',
#   'series',
#   'bang',
#   'craze',
#   'love',
#   'checkPixel',
#   'series',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'powerful',
#   'device',
#   'Nexus',
#   'series',
#   'craze',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'high',
#   'price',
#   'obvious',
#   'option',
#   'success',
#   'bang',
#   'performance',
#   'checknew',
#   'flagship',
#   'phone',
#   'korean',
#   'tech',
#   'giant',
#   'Samsung',
#   'Galaxy',
#   'S8',
#   'specification',
#   'demand',
#   'budget',
#   'best',
#   'features',
#   'splendid',
#   'smartphone',
#   'barrier',
#   'consumers',
#   'releasebest',
#   'smartphone',
#   'sound',
#   'performance',
#   'curved',
#   'display',
#   'S-Pen',
#   'wireless',
#   'charging',
#   'support',
#   'great',
#   'photography',
#   'capabilities',
#   'high',
#   'price',
#   'tag',
#   'Samsung',
#   'Galaxy',
#   'marketpower-packed',
#   'device',
#   'great',
#   'smartphone',
#   'experience',
#   'selfie',
#   'camera',
#   'powerhouse',
#   'terms',
#   'performance',
#   'storage',
#   'cameras',
#   'major',
#   'highlight',
#   'tablet',
#   'users',
#   'quick',
#   'charging',
#   'feature',
#   'perfect',
#   'blend',
#   'Samsung',
#   'Galaxy',
#   'A8',
#   'battery',
#   'backup',
#   'phabletprocessor',
#   'battery',
#   'powerful',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'C9',
#   'Pro',
#   'great',
#   'display',
#   'premium',
#   'smartphone',
#   'cameras',
#   'peerssmartphone',
#   'contenders',
#   'elegant',
#   'metal',
#   'outfit',
#   'scaled',
#   'hardware',
#   'lower',
#   'pixel',
#   'density',
#   'avid',
#   'photographer',
#   'midrange',
#   'flagship',
#   'Samsung',
#   'Galaxy',
#   'C7',
#   'Pro',
#   'trustworthy',
#   'brand',
#   'issue',
#   'selfie',
#   'fanatic',
#   'budget',
#   'Connectivitynew',
#   'Samsung',
#   'Galaxy',
#   'J7',
#   'powerful',
#   'processor',
#   'good',
#   'features',
#   'good',
#   'display',
#   'elegant',
#   'smartphone',
#   'Korean',
#   'electronics',
#   'giant',
#   'excellent',
#   'design',
#   'Samsung',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'exciting',
#   'cameras',
#   'mid',
#   'range',
#   'portfolio',
#   'phabletsnew',
#   'edition',
#   'Samsung',
#   'Galaxy',
#   'J5',
#   'extension',
#   'company',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'smartphones',
#   'power',
#   'hearts',
#   'photo',
#   'crazy',
#   'youngsters',
#   'mid',
#   'range',
#   'device',
#   'efforts',
#   'excellent',
#   'pair',
#   'cameras',
#   'better',
#   'features',
#   'downside',
#   'priceGB',
#   'Samsung',
#   'Galaxy',
#   'On7',
#   'Prime',
#   'HD',
#   'videos',
#   'premium',
#   'smartphone',
#   'massive',
#   'storage',
#   'excellent',
#   'pair',
#   'cameras',
#   'powerful',
#   'mid-range',
#   'device',
#   'entertainment',
#   'scope',
#   'lot',
#   'strong',
#   'features',
#   'high-resolution',
#   'imageslatest',
#   'mid',
#   'range',
#   'device',
#   'Smart',
#   'Glow',
#   'ring',
#   'Turbo',
#   'Speed',
#   'Technology',
#   'Samsung',
#   "'s",
#   'popular',
#   'ultra',
#   'data',
#   'innovative',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'J2',
#   'Pro',
#   'South',
#   'Korean',
#   'tech',
#   'giant',
#   'S',
#   'bike',
#   'mode',
#   'combination',
#   'good',
#   'looks',
#   'powerful',
#   'performance',
#   'handsetSamsung',
#   'Galaxy',
#   'S7',
#   'Edge',
#   'Additional',
#   'features',
#   'monster',
#   'waterproof',
#   'D',
#   'glass',
#   'terms',
#   'specs',
#   'metal',
#   'body',
#   'dust',
#   'phones',
#   'dual',
#   'pixel',
#   'camera',
#   'beauty',
#   'perfect',
#   'choiceOnePlus',
#   'high',
#   'internal',
#   'storage',
#   'leaves',
#   'high',
#   'price',
#   'tag',
#   'big',
#   'battery',
#   'backup',
#   'smart',
#   'connectivity',
#   'features',
#   'league',
#   'smartphones',
#   'Chinese',
#   'smartphone',
#   'maker',
#   'powerful',
#   'processors',
#   'camera',
#   'segment',
#   'different',
#   'levelamazing',
#   'smartphone',
#   'smartphone',
#   'work',
#   'amazing',
#   'pair',
#   'cameras',
#   'massive',
#   'internal',
#   'storage',
#   'sharp',
#   'display',
#   'tandem',
#   'high-performance',
#   'processor',
#   'beast',
#   'mode',
#   'time',
#   'OnePlus',
#   'correct',
#   'boxes',
#   'calibre',
#   'superior',
#   'quality',
#   'features',
#   'price',
#   'tag',
#   'device',
#   'sectionSamsung',
#   'Galaxy',
#   'S9',
#   'waterproof',
#   'body',
#   'stylish',
#   'body',
#   'power',
#   'packed',
#   'smartphone',
#   'nice',
#   'features',
#   'cameras',
#   'battery',
#   'backup',
#   'display',
#   'quality',
#   'quick',
#   'charging',
#   'support',
#   'user',
#   'desires',
#   'sound',
#   'performer',
#   'elements',
#   'brandpowerful',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'house',
#   'HTC',
#   'better',
#   'optionrobust',
#   'configured',
#   'handset',
#   'long',
#   'hours',
#   'ones',
#   'Pro',
#   'G',
#   'connectivity',
#   'battery',
#   'backup',
#   'large',
#   'number',
#   'high',
#   'sized',
#   'files',
#   'marvellous',
#   'cameras',
#   'ample',
#   'expandable',
#   'memory',
#   'HTC',
#   'Desire',
#   'flash',
#   'good',
#   'thing',
#   'userssmartphone',
#   'feeds',
#   'powerful',
#   'smartphone',
#   'fromt',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'house',
#   'HTC',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'better',
#   'option',
#   'HTC',
#   'U',
#   'Play',
#   'humongous',
#   'storage',
#   'option',
#   'wouldnHTC',
#   'LifeStyle',
#   'good',
#   'specification',
#   'good',
#   'option',
#   'rounder',
#   'phone',
#   'gorgeous',
#   'looking',
#   'smartphones',
#   'view',
#   'metallic',
#   'frame',
#   'slips',
#   'everyday',
#   'life',
#   'bumps',
#   'India',
#   'latest',
#   'features',
#   'price',
#   'segmentCDMA',
#   'phone',
#   'nice',
#   'cameras',
#   'octa-core',
#   'processor',
#   'GSM',
#   'better',
#   'battery',
#   'additional',
#   'package',
#   'HTC',
#   'Desire',
#   'perfect',
#   'device',
#   'onesimpressive',
#   'features',
#   'lot',
#   'features',
#   'high-end',
#   'smartphones',
#   'promising',
#   'smartphone',
#   'current',
#   'market',
#   'trend',
#   'affordable',
#   'price',
#   'tag',
#   'Xiaomi',
#   'Redmi',
#   'departmentsXiaomi',
#   'Redmi',
#   'metal',
#   'Redmi',
#   'series',
#   'body',
#   'uniform',
#   'metal',
#   'texture',
#   'multitasking',
#   'apps',
#   'high',
#   'games',
#   'GB',
#   'stage',
#   'independent',
#   'space',
#   'system',
#   'additional',
#   'cell',
#   'phone',
#   'users',
#   'perfect',
#   'allrounder',
#   'handset',
#   'lagNokia',
#   'series',
#   'Nokia',
#   'company',
#   'quick-charging',
#   'good',
#   'battery',
#   'backup',
#   'excellent',
#   'cameras',
#   'great',
#   'configuration',
#   'impressive',
#   'display',
#   'addition',
#   'class',
#   'performance',
#   'aspects',
#   'phone',
#   'worthy',
#   'profitable',
#   'choice',
#   'concluding',
#   'note',
#   'winner',
#   'mobiles',
#   'year'],
#  ['Apple',
#   'iPhone',
#   'X',
#   'new',
#   'iPhone',
#   'home',
#   'button',
#   'fingerprint',
#   'scanner',
#   'FaceID',
#   'groundbreaking',
#   'launches',
#   'technology',
#   'big',
#   'time',
#   'design',
#   'departmentpowerful',
#   'flagship',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'flagship',
#   'smartphones',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'LG',
#   'G6',
#   'house',
#   'LG',
#   'better',
#   'optionnotch',
#   'norm',
#   'manufacturing',
#   'smartphones',
#   'best',
#   'love',
#   'high-end',
#   'brand',
#   'configuration',
#   'battery',
#   'huge',
#   'bucks',
#   'predecessor',
#   'ways',
#   'iPhones',
#   'Applelarger',
#   'brain',
#   'larger',
#   'battery',
#   'backup',
#   'beauty',
#   'worth',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'options',
#   'bag',
#   'amazing',
#   'camera',
#   'flagship',
#   'patented',
#   'features',
#   'latest',
#   'iOS',
#   'smartphone',
#   'powerful',
#   'processor',
#   'good',
#   'buy',
#   'Apple',
#   'iPhone',
#   'tasksseries',
#   'smartphones',
#   'previous',
#   'iPhone',
#   'iPhone',
#   'SE',
#   'Apple',
#   "'s",
#   'newiPhone',
#   'smaller',
#   'version',
#   'upgraded',
#   'features',
#   'goodness',
#   'users',
#   'attentioniPhone',
#   'SE',
#   'previous',
#   'iPhone',
#   'premium',
#   'phone',
#   'premium',
#   'price',
#   'tag',
#   'series',
#   'smartphones',
#   'flagship',
#   'device',
#   'bag',
#   'patented',
#   'features',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'decent',
#   'performing',
#   'configuration',
#   'good',
#   'buypowerful',
#   'device',
#   'users',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'high',
#   'price',
#   'excellent',
#   'display',
#   'properties',
#   'success',
#   'Nexus',
#   'series',
#   'bang',
#   'craze',
#   'love',
#   'checkPixel',
#   'series',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'powerful',
#   'device',
#   'Nexus',
#   'series',
#   'craze',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'high',
#   'price',
#   'obvious',
#   'option',
#   'success',
#   'bang',
#   'performance',
#   'checknew',
#   'flagship',
#   'phone',
#   'korean',
#   'tech',
#   'giant',
#   'Samsung',
#   'Galaxy',
#   'S8',
#   'specification',
#   'demand',
#   'budget',
#   'best',
#   'features',
#   'splendid',
#   'smartphone',
#   'barrier',
#   'consumers',
#   'releasebest',
#   'smartphone',
#   'sound',
#   'performance',
#   'curved',
#   'display',
#   'S-Pen',
#   'wireless',
#   'charging',
#   'support',
#   'great',
#   'photography',
#   'capabilities',
#   'high',
#   'price',
#   'tag',
#   'Samsung',
#   'Galaxy',
#   'marketpower-packed',
#   'device',
#   'great',
#   'smartphone',
#   'experience',
#   'selfie',
#   'camera',
#   'powerhouse',
#   'terms',
#   'performance',
#   'storage',
#   'cameras',
#   'major',
#   'highlight',
#   'tablet',
#   'users',
#   'quick',
#   'charging',
#   'feature',
#   'perfect',
#   'blend',
#   'Samsung',
#   'Galaxy',
#   'A8',
#   'battery',
#   'backup',
#   'phabletprocessor',
#   'battery',
#   'powerful',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'C9',
#   'Pro',
#   'great',
#   'display',
#   'premium',
#   'smartphone',
#   'cameras',
#   'peerssmartphone',
#   'contenders',
#   'elegant',
#   'metal',
#   'outfit',
#   'scaled',
#   'hardware',
#   'lower',
#   'pixel',
#   'density',
#   'avid',
#   'photographer',
#   'midrange',
#   'flagship',
#   'Samsung',
#   'Galaxy',
#   'C7',
#   'Pro',
#   'trustworthy',
#   'brand',
#   'issue',
#   'selfie',
#   'fanatic',
#   'budget',
#   'Connectivitynew',
#   'Samsung',
#   'Galaxy',
#   'J7',
#   'powerful',
#   'processor',
#   'good',
#   'features',
#   'good',
#   'display',
#   'elegant',
#   'smartphone',
#   'Korean',
#   'electronics',
#   'giant',
#   'excellent',
#   'design',
#   'Samsung',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'exciting',
#   'cameras',
#   'mid',
#   'range',
#   'portfolio',
#   'phabletsnew',
#   'edition',
#   'Samsung',
#   'Galaxy',
#   'J5',
#   'extension',
#   'company',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'smartphones',
#   'power',
#   'hearts',
#   'photo',
#   'crazy',
#   'youngsters',
#   'mid',
#   'range',
#   'device',
#   'efforts',
#   'excellent',
#   'pair',
#   'cameras',
#   'better',
#   'features',
#   'downside',
#   'priceGB',
#   'Samsung',
#   'Galaxy',
#   'On7',
#   'Prime',
#   'HD',
#   'videos',
#   'premium',
#   'smartphone',
#   'massive',
#   'storage',
#   'excellent',
#   'pair',
#   'cameras',
#   'powerful',
#   'mid-range',
#   'device',
#   'entertainment',
#   'scope',
#   'lot',
#   'strong',
#   'features',
#   'high-resolution',
#   'imageslatest',
#   'mid',
#   'range',
#   'device',
#   'Smart',
#   'Glow',
#   'ring',
#   'Turbo',
#   'Speed',
#   'Technology',
#   'Samsung',
#   "'s",
#   'popular',
#   'ultra',
#   'data',
#   'innovative',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'J2',
#   'Pro',
#   'South',
#   'Korean',
#   'tech',
#   'giant',
#   'S',
#   'bike',
#   'mode',
#   'combination',
#   'good',
#   'looks',
#   'powerful',
#   'performance',
#   'handsetSamsung',
#   'Galaxy',
#   'S7',
#   'Edge',
#   'Additional',
#   'features',
#   'monster',
#   'waterproof',
#   'D',
#   'glass',
#   'terms',
#   'specs',
#   'metal',
#   'body',
#   'dust',
#   'phones',
#   'dual',
#   'pixel',
#   'camera',
#   'beauty',
#   'perfect',
#   'choiceOnePlus',
#   'high',
#   'internal',
#   'storage',
#   'leaves',
#   'high',
#   'price',
#   'tag',
#   'big',
#   'battery',
#   'backup',
#   'smart',
#   'connectivity',
#   'features',
#   'league',
#   'smartphones',
#   'Chinese',
#   'smartphone',
#   'maker',
#   'powerful',
#   'processors',
#   'camera',
#   'segment',
#   'different',
#   'levelamazing',
#   'smartphone',
#   'smartphone',
#   'work',
#   'amazing',
#   'pair',
#   'cameras',
#   'massive',
#   'internal',
#   'storage',
#   'sharp',
#   'display',
#   'tandem',
#   'high-performance',
#   'processor',
#   'beast',
#   'mode',
#   'time',
#   'OnePlus',
#   'correct',
#   'boxes',
#   'calibre',
#   'superior',
#   'quality',
#   'features',
#   'price',
#   'tag',
#   'device',
#   'sectionSamsung',
#   'Galaxy',
#   'S9',
#   'waterproof',
#   'body',
#   'stylish',
#   'body',
#   'power',
#   'packed',
#   'smartphone',
#   'nice',
#   'features',
#   'cameras',
#   'battery',
#   'backup',
#   'display',
#   'quality',
#   'quick',
#   'charging',
#   'support',
#   'user',
#   'desires',
#   'sound',
#   'performer',
#   'elements',
#   'brandpowerful',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'house',
#   'HTC',
#   'better',
#   'optionrobust',
#   'configured',
#   'handset',
#   'long',
#   'hours',
#   'ones',
# ...
#   'huge',
#   'bucks',
#   'predecessor',
#   'ways',
#   'iPhones',
#   'Applelarger',
#   'brain',
#   'larger',
#   'battery',
#   'backup',
#   'beauty',
#   'worth',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'options',
#   'bag',
#   'amazing',
#   'camera',
#   'flagship',
#   'patented',
#   'features',
#   'latest',
#   'iOS',
#   'smartphone',
#   'powerful',
#   'processor',
#   'good',
#   'buy',
#   'Apple',
#   'iPhone',
#   'tasksseries',
#   'smartphones',
#   'previous',
#   'iPhone',
#   'iPhone',
#   'SE',
#   'Apple',
#   "'s",
#   'newiPhone',
#   'smaller',
#   'version',
#   'upgraded',
#   'features',
#   'goodness',
#   'users',
#   'attentioniPhone',
#   'SE',
#   'previous',
#   'iPhone',
#   'premium',
#   'phone',
#   'premium',
#   'price',
#   'tag',
#   'series',
#   'smartphones',
#   'flagship',
#   'device',
#   'bag',
#   'patented',
#   'features',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'decent',
#   'performing',
#   'configuration',
#   'good',
#   'buypowerful',
#   'device',
#   'users',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'high',
#   'price',
#   'excellent',
#   'display',
#   'properties',
#   'success',
#   'Nexus',
#   'series',
#   'bang',
#   'craze',
#   'love',
#   'checkPixel',
#   'series',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'powerful',
#   'device',
#   'Nexus',
#   'series',
#   'craze',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'high',
#   'price',
#   'obvious',
#   'option',
#   'success',
#   'bang',
#   'performance',
#   'checknew',
#   'flagship',
#   'phone',
#   'korean',
#   'tech',
#   'giant',
#   'Samsung',
#   'Galaxy',
#   'S8',
#   'specification',
#   'demand',
#   'budget',
#   'best',
#   'features',
#   'splendid',
#   'smartphone',
#   'barrier',
#   'consumers',
#   'releasebest',
#   'smartphone',
#   'sound',
#   'performance',
#   'curved',
#   'display',
#   'S-Pen',
#   'wireless',
#   'charging',
#   'support',
#   'great',
#   'photography',
#   'capabilities',
#   'high',
#   'price',
#   'tag',
#   'Samsung',
#   'Galaxy',
#   'marketpower-packed',
#   'device',
#   'great',
#   'smartphone',
#   'experience',
#   'selfie',
#   'camera',
#   'powerhouse',
#   'terms',
#   'performance',
#   'storage',
#   'cameras',
#   'major',
#   'highlight',
#   'tablet',
#   'users',
#   'quick',
#   'charging',
#   'feature',
#   'perfect',
#   'blend',
#   'Samsung',
#   'Galaxy',
#   'A8',
#   'battery',
#   'backup',
#   'phabletprocessor',
#   'battery',
#   'powerful',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'C9',
#   'Pro',
#   'great',
#   'display',
#   'premium',
#   'smartphone',
#   'cameras',
#   'peerssmartphone',
#   'contenders',
#   'elegant',
#   'metal',
#   'outfit',
#   'scaled',
#   'hardware',
#   'lower',
#   'pixel',
#   'density',
#   'avid',
#   'photographer',
#   'midrange',
#   'flagship',
#   'Samsung',
#   'Galaxy',
#   'C7',
#   'Pro',
#   'trustworthy',
#   'brand',
#   'issue',
#   'selfie',
#   'fanatic',
#   'budget',
#   'Connectivitynew',
#   'Samsung',
#   'Galaxy',
#   'J7',
#   'powerful',
#   'processor',
#   'good',
#   'features',
#   'good',
#   'display',
#   'elegant',
#   'smartphone',
#   'Korean',
#   'electronics',
#   'giant',
#   'excellent',
#   'design',
#   'Samsung',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'exciting',
#   'cameras',
#   'mid',
#   'range',
#   'portfolio',
#   'phabletsnew',
#   'edition',
#   'Samsung',
#   'Galaxy',
#   'J5',
#   'extension',
#   'company',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'smartphones',
#   'power',
#   'hearts',
#   'photo',
#   'crazy',
#   'youngsters',
#   'mid',
#   'range',
#   'device',
#   'efforts',
#   'excellent',
#   'pair',
#   'cameras',
#   'better',
#   'features',
#   'downside',
#   'priceGB',
#   'Samsung',
#   'Galaxy',
#   'On7',
#   'Prime',
#   'HD',
#   'videos',
#   'premium',
#   'smartphone',
#   'massive',
#   'storage',
#   'excellent',
#   'pair',
#   'cameras',
#   'powerful',
#   'mid-range',
#   'device',
#   'entertainment',
#   'scope',
#   'lot',
#   'strong',
#   'features',
#   'high-resolution',
#   'imageslatest',
#   'mid',
#   'range',
#   'device',
#   'Smart',
#   'Glow',
#   'ring',
#   'Turbo',
#   'Speed',
#   'Technology',
#   'Samsung',
#   "'s",
#   'popular',
#   'ultra',
#   'data',
#   'innovative',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'J2',
#   'Pro',
#   'South',
#   'Korean',
#   'tech',
#   'giant',
#   'S',
#   'bike',
#   'mode',
#   'combination',
#   'good',
#   'looks',
#   'powerful',
#   'performance',
#   'handsetSamsung',
#   'Galaxy',
#   'S7',
#   'Edge',
#   'Additional',
#   'features',
#   'monster',
#   'waterproof',
#   'D',
#   'glass',
#   'terms',
#   'specs',
#   'metal',
#   'body',
#   'dust',
#   'phones',
#   'dual',
#   'pixel',
#   'camera',
#   'beauty',
#   'perfect',
#   'choiceOnePlus',
#   'high',
#   'internal',
#   'storage',
#   'leaves',
#   'high',
#   'price',
#   'tag',
#   'big',
#   'battery',
#   'backup',
#   'smart',
#   'connectivity',
#   'features',
#   'league',
#   'smartphones',
#   'Chinese',
#   'smartphone',
#   'maker',
#   'powerful',
#   'processors',
#   'camera',
#   'segment',
#   'different',
#   'levelamazing',
#   'smartphone',
#   'smartphone',
#   'work',
#   'amazing',
#   'pair',
#   'cameras',
#   'massive',
#   'internal',
#   'storage',
#   'sharp',
#   'display',
#   'tandem',
#   'high-performance',
#   'processor',
#   'beast',
#   'mode',
#   'time',
#   'OnePlus',
#   'correct',
#   'boxes',
#   'calibre',
#   'superior',
#   'quality',
#   'features',
#   'price',
#   'tag',
#   'device',
#   'sectionSamsung',
#   'Galaxy',
#   'S9',
#   'waterproof',
#   'body',
#   'stylish',
#   'body',
#   'power',
#   'packed',
#   'smartphone',
#   'nice',
#   'features',
#   'cameras',
#   'battery',
#   'backup',
#   'display',
#   'quality',
#   'quick',
#   'charging',
#   'support',
#   'user',
#   'desires',
#   'sound',
#   'performer',
#   'elements',
#   'brandpowerful',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'house',
#   'HTC',
#   'better',
#   'optionrobust',
#   'configured',
#   'handset',
#   'long',
#   'hours',
#   'ones',
#   'Pro',
#   'G',
#   'connectivity',
#   'battery',
#   'backup',
#   'large',
#   'number',
#   'high',
#   'sized',
#   'files',
#   'marvellous',
#   'cameras',
#   'ample',
#   'expandable',
#   'memory',
#   'HTC',
#   'Desire',
#   'flash',
#   'good',
#   'thing',
#   'userssmartphone',
#   'feeds',
#   'powerful',
#   'smartphone',
#   'fromt',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'house',
#   'HTC',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'better',
#   'option',
#   'HTC',
#   'U',
#   'Play',
#   'humongous',
#   'storage',
#   'option',
#   'wouldnHTC',
#   'LifeStyle',
#   'good',
#   'specification',
#   'good',
#   'option',
#   'rounder',
#   'phone',
#   'gorgeous',
#   'looking',
#   'smartphones',
#   'view',
#   'metallic',
#   'frame',
#   'slips',
#   'everyday',
#   'life',
#   'bumps',
#   'India',
#   'latest',
#   'features',
#   'price',
#   'segmentCDMA',
#   'phone',
#   'nice',
#   'cameras',
#   'octa-core',
#   'processor',
#   'GSM',
#   'better',
#   'battery',
#   'additional',
#   'package',
#   'HTC',
#   'Desire',
#   'perfect',
#   'device',
#   'onesimpressive',
#   'features',
#   'lot',
#   'features',
#   'high-end',
#   'smartphones',
#   'promising',
#   'smartphone',
#   'current',
#   'market',
#   'trend',
#   'affordable',
#   'price',
#   'tag',
#   'Xiaomi',
#   'Redmi',
#   'departmentsXiaomi',
#   'Redmi',
#   'metal',
#   'Redmi',
#   'series',
#   'body',
#   'uniform',
#   'metal',
#   'texture',
#   'multitasking',
#   'apps',
#   'high',
#   'games',
#   'GB',
#   'stage',
#   'independent',
#   'space',
#   'system',
#   'additional',
#   'cell',
#   'phone',
#   'users',
#   'perfect',
#   'allrounder',
#   'handset',
#   'lagNokia',
#   'series',
#   'Nokia',
#   'company',
#   'quick-charging',
#   'good',
#   'battery',
#   'backup',
#   'excellent',
#   'cameras',
#   'great',
#   'configuration',
#   'impressive',
#   'display',
#   'addition',
#   'class',
#   'performance',
#   'aspects',
#   'phone',
#   'worthy',
#   'profitable',
#   'choice',
#   'concluding',
#   'note',
#   'winner',
#   'mobiles',
#   'year'],
#  ['Apple',
#   'iPhone',
#   'X',
#   'new',
#   'iPhone',
#   'home',
#   'button',
#   'fingerprint',
#   'scanner',
#   'FaceID',
#   'groundbreaking',
#   'launches',
#   'technology',
#   'big',
#   'time',
#   'design',
#   'departmentpowerful',
#   'flagship',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'flagship',
#   'smartphones',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'LG',
#   'G6',
#   'house',
#   'LG',
#   'better',
#   'optionnotch',
#   'norm',
#   'manufacturing',
#   'smartphones',
#   'best',
#   'love',
#   'high-end',
#   'brand',
#   'configuration',
#   'battery',
#   'huge',
#   'bucks',
#   'predecessor',
#   'ways',
#   'iPhones',
#   'Applelarger',
#   'brain',
#   'larger',
#   'battery',
#   'backup',
#   'beauty',
#   'worth',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'options',
#   'bag',
#   'amazing',
#   'camera',
#   'flagship',
#   'patented',
#   'features',
#   'latest',
#   'iOS',
#   'smartphone',
#   'powerful',
#   'processor',
#   'good',
#   'buy',
#   'Apple',
#   'iPhone',
#   'tasksseries',
#   'smartphones',
#   'previous',
#   'iPhone',
#   'iPhone',
#   'SE',
#   'Apple',
#   "'s",
#   'newiPhone',
#   'smaller',
#   'version',
#   'upgraded',
#   'features',
#   'goodness',
#   'users',
#   'attentioniPhone',
#   'SE',
#   'previous',
#   'iPhone',
#   'premium',
#   'phone',
#   'premium',
#   'price',
#   'tag',
#   'series',
#   'smartphones',
#   'flagship',
#   'device',
#   'bag',
#   'patented',
#   'features',
#   'wide',
#   'arrayed',
#   'connectivity',
#   'decent',
#   'performing',
#   'configuration',
#   'good',
#   'buypowerful',
#   'device',
#   'users',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'high',
#   'price',
#   'excellent',
#   'display',
#   'properties',
#   'success',
#   'Nexus',
#   'series',
#   'bang',
#   'craze',
#   'love',
#   'checkPixel',
#   'series',
#   'good',
#   'pair',
#   'cameras',
#   'Pixel',
#   'XL',
#   'powerful',
#   'device',
#   'Nexus',
#   'series',
#   'craze',
#   'Google',
#   'little',
#   'features',
#   'latest',
#   'version',
#   'Android',
#   'OS',
#   'high',
#   'price',
#   'obvious',
#   'option',
#   'success',
#   'bang',
#   'performance',
#   'checknew',
#   'flagship',
#   'phone',
#   'korean',
#   'tech',
#   'giant',
#   'Samsung',
#   'Galaxy',
#   'S8',
#   'specification',
#   'demand',
#   'budget',
#   'best',
#   'features',
#   'splendid',
#   'smartphone',
#   'barrier',
#   'consumers',
#   'releasebest',
#   'smartphone',
#   'sound',
#   'performance',
#   'curved',
#   'display',
#   'S-Pen',
#   'wireless',
#   'charging',
#   'support',
#   'great',
#   'photography',
#   'capabilities',
#   'high',
#   'price',
#   'tag',
#   'Samsung',
#   'Galaxy',
#   'marketpower-packed',
#   'device',
#   'great',
#   'smartphone',
#   'experience',
#   'selfie',
#   'camera',
#   'powerhouse',
#   'terms',
#   'performance',
#   'storage',
#   'cameras',
#   'major',
#   'highlight',
#   'tablet',
#   'users',
#   'quick',
#   'charging',
#   'feature',
#   'perfect',
#   'blend',
#   'Samsung',
#   'Galaxy',
#   'A8',
#   'battery',
#   'backup',
#   'phabletprocessor',
#   'battery',
#   'powerful',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'C9',
#   'Pro',
#   'great',
#   'display',
#   'premium',
#   'smartphone',
#   'cameras',
#   'peerssmartphone',
#   'contenders',
#   'elegant',
#   'metal',
#   'outfit',
#   'scaled',
#   'hardware',
#   'lower',
#   'pixel',
#   'density',
#   'avid',
#   'photographer',
#   'midrange',
#   'flagship',
#   'Samsung',
#   'Galaxy',
#   'C7',
#   'Pro',
#   'trustworthy',
#   'brand',
#   'issue',
#   'selfie',
#   'fanatic',
#   'budget',
#   'Connectivitynew',
#   'Samsung',
#   'Galaxy',
#   'J7',
#   'powerful',
#   'processor',
#   'good',
#   'features',
#   'good',
#   'display',
#   'elegant',
#   'smartphone',
#   'Korean',
#   'electronics',
#   'giant',
#   'excellent',
#   'design',
#   'Samsung',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'exciting',
#   'cameras',
#   'mid',
#   'range',
#   'portfolio',
#   'phabletsnew',
#   'edition',
#   'Samsung',
#   'Galaxy',
#   'J5',
#   'extension',
#   'company',
#   "'s",
#   'youngest',
#   'J',
#   'series',
#   'smartphones',
#   'power',
#   'hearts',
#   'photo',
#   'crazy',
#   'youngsters',
#   'mid',
#   'range',
#   'device',
#   'efforts',
#   'excellent',
#   'pair',
#   'cameras',
#   'better',
#   'features',
#   'downside',
#   'priceGB',
#   'Samsung',
#   'Galaxy',
#   'On7',
#   'Prime',
#   'HD',
#   'videos',
#   'premium',
#   'smartphone',
#   'massive',
#   'storage',
#   'excellent',
#   'pair',
#   'cameras',
#   'powerful',
#   'mid-range',
#   'device',
#   'entertainment',
#   'scope',
#   'lot',
#   'strong',
#   'features',
#   'high-resolution',
#   'imageslatest',
#   'mid',
#   'range',
#   'device',
#   'Smart',
#   'Glow',
#   'ring',
#   'Turbo',
#   'Speed',
#   'Technology',
#   'Samsung',
#   "'s",
#   'popular',
#   'ultra',
#   'data',
#   'innovative',
#   'features',
#   'Samsung',
#   'Galaxy',
#   'J2',
#   'Pro',
#   'South',
#   'Korean',
#   'tech',
#   'giant',
#   'S',
#   'bike',
#   'mode',
#   'combination',
#   'good',
#   'looks',
#   'powerful',
#   'performance',
#   'handsetSamsung',
#   'Galaxy',
#   'S7',
#   'Edge',
#   'Additional',
#   'features',
#   'monster',
#   'waterproof',
#   'D',
#   'glass',
#   'terms',
#   'specs',
#   'metal',
#   'body',
#   'dust',
#   'phones',
#   'dual',
#   'pixel',
#   'camera',
#   'beauty',
#   'perfect',
#   'choiceOnePlus',
#   'high',
#   'internal',
#   'storage',
#   'leaves',
#   'high',
#   'price',
#   'tag',
#   'big',
#   'battery',
#   'backup',
#   'smart',
#   'connectivity',
#   'features',
#   'league',
#   'smartphones',
#   'Chinese',
#   'smartphone',
#   'maker',
#   'powerful',
#   'processors',
#   'camera',
#   'segment',
#   'different',
#   'levelamazing',
#   'smartphone',
#   'smartphone',
#   'work',
#   'amazing',
#   'pair',
#   'cameras',
#   'massive',
#   'internal',
#   'storage',
#   'sharp',
#   'display',
#   'tandem',
#   'high-performance',
#   'processor',
#   'beast',
#   'mode',
#   'time',
#   'OnePlus',
#   'correct',
#   'boxes',
#   'calibre',
#   'superior',
#   'quality',
#   'features',
#   'price',
#   'tag',
#   'device',
#   'sectionSamsung',
#   'Galaxy',
#   'S9',
#   'waterproof',
#   'body',
#   'stylish',
#   'body',
#   'power',
#   'packed',
#   'smartphone',
#   'nice',
#   'features',
#   'cameras',
#   'battery',
#   'backup',
#   'display',
#   'quality',
#   'quick',
#   'charging',
#   'support',
#   'user',
#   'desires',
#   'sound',
#   'performer',
#   'elements',
#   'brandpowerful',
#   'smartphone',
#   'smartphone',
#   'feeds',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'house',
#   'HTC',
#   'better',
#   'optionrobust',
#   'configured',
#   'handset',
#   'long',
#   'hours',
#   'ones',
#   'Pro',
#   'G',
#   'connectivity',
#   'battery',
#   'backup',
#   'large',
#   'number',
#   'high',
#   'sized',
#   'files',
#   'marvellous',
#   'cameras',
#   'ample',
#   'expandable',
#   'memory',
#   'HTC',
#   'Desire',
#   'flash',
#   'good',
#   'thing',
#   'userssmartphone',
#   'feeds',
#   'powerful',
#   'smartphone',
#   'fromt',
#   'Indian',
#   'smartphone',
#   'market',
#   'great',
#   'camera',
#   'quality',
#   'powerful',
#   'processor',
#   'house',
#   'HTC',
#   'large',
#   'number',
#   'great',
#   'quality',
#   'smartphones',
#   'better',
#   'option',
#   'HTC',
#   'U',
#   'Play',
#   'humongous',
#   'storage',
#   'option',
#   'wouldnHTC',
#   'LifeStyle',
#   'good',
#   'specification',
#   'good',
#   'option',
#   'rounder',
#   'phone',
#   'gorgeous',
#   'looking',
#   'smartphones',
#   'view',
#   'metallic',
#   'frame',
#   'slips',
#   'everyday',
#   'life',
#   'bumps',
#   'India',
#   'latest',
#   'features',
#   'price',
#   'segmentCDMA',
#   'phone',
#   'nice',
#   'cameras',
#   'octa-core',
#   'processor',
#   'GSM',
#   'better',
#   'battery',
#   'additional',
#   'package',
#   'HTC',
#   'Desire',
#   'perfect',
#   'device',
#   'onesimpressive',
#   'features',
#   'lot',
#   'features',
#   'high-end',
#   'smartphones',
#   'promising',
#   'smartphone',
#   'current',
#   'market',
#   'trend',
#   'affordable',
#   'price',
#   'tag',
#   'Xiaomi',
#   'Redmi',
#   'departmentsXiaomi',
#   'Redmi',
#   'metal',
#   'Redmi',
#   'series',
#   'body',
#   'uniform',
#   'metal',
#   'texture',
#   'multitasking',
#   'apps',
#   'high',
#   'games',
#   'GB',
#   'stage',
#   'independent',
#   'space',
#   'system',
#   'additional',
#   'cell',
#   'phone',
#   'users',
#   'perfect',
#   'allrounder',
#   'handset',
#   'lagNokia',
#   'series',
#   'Nokia',
#   'company',
#   'quick-charging',
#   'good',
#   'battery',
#   'backup',
#   'excellent',
#   'cameras',
#   'great',
#   'configuration',
#   'impressive',
#   'display',
#   'addition',
#   'class',
#   'performance',
#   'aspects',
#   'phone',
#   'worthy',
#   'profitable',
#   'choice',
#   'concluding',
#   'note',
#   'winner',
#   'mobiles',
#   'year']]

# %%
def build_corpus(data):
    "Creates a list of lists containing words from each sentence"
    corpus = []
    for col in ['question1', 'question2']:
        for sentence in data[col].iteritems():
            word_list = sentence[1].split(" ")
            corpus.append(word_list)
            
    return corpus

corpus = build_corpus(data)        
corpus[0:2]
# Out:
# [['sex', 'necessary', 'relationship'], ['inspiring', 'start', 'stories']]

# %%
model = word2vec.Word2Vec(d, size=100)

# %%
corpus
# Out:
# [['sex', 'necessary', 'relationship'],
#  ['inspiring', 'start', 'stories'],
#  ['best', 'way', 'digital', 'marketing'],
#  ['best', 'way', 'grow', 'facebook', 'fan', 'page'],
#  ['suppose',
#   'host',
#   'sends',
#   'two',
#   'tcp',
#   'segments',
#   'back',
#   'back',
#   'host',
#   'b',
#   'tcp',
#   'connection',
#   'first',
#   'segment',
#   'sequence',
#   'number',
#   '140',
#   'second',
#   'sequence',
#   'number',
#   '170'],
#  ['sahara', 'average', 'temperatures', 'compare', 'ones', 'dashte', 'loot'],
#  ['possible', 'disable', 'facetimes', 'call', 'button'],
#  ['agencies', 'fulfil', 'sex', 'fantasies', 'usa'],
#  ['signs', 'mentally', 'weak'],
#  ['different', 'quora'],
#  ['find', 'list', 'gmail', 'addresses'],
#  ['best', 'resources', 'learning', 'sap', 'hana'],
#  ['best', 'business', 'opportunities', 'india'],
#  ['coding', 'language', 'learn', 'first', 'making', 'games'],
#  ['interesting', 'products', 'innovations', 'brands', 'coming', '2016'],
#  ['question',
#   'quora',
#   'marked',
#   'needing',
#   'improvement',
#   'make',
#   'invisible'],
#  ['expected',
#   'cut',
#   'ssc',
#   'cgl',
#   'tier',
#   '1',
#   '2016',
#   'cut',
#   'rise',
#   'paper',
#   'easy',
#   'vacancies',
#   'less'],
#  ['mrs',
#   'clinton',
#   'denying',
#   'lied',
#   'congress',
#   'information',
#   'personal',
#   'servers'],
#  ['uk', 'never', 'apologize', 'china', 'aggression'],
#  ['quora', 'page', 'slow', 'load'],
#  ['nibm', 'pune', 'expected', 'cutoff'],
#  ['drive',
#   'edmonton',
#   'auckland',
#   'described',
#   'cities',
#   'attractions',
#   'compare',
#   'london'],
#  ['person',
#   'china',
#   'receive',
#   'incoming',
#   'email',
#   'gmail',
#   'currently',
#   'blocked',
#   '163com',
#   'blocked'],
#  ['angelina',
#   'jolie',
#   'antonio',
#   'banderas',
#   'real',
#   'sexual',
#   'intercourse',
#   'movie',
#   'original'],
#  ['people',
#   'mark',
#   'questions',
#   'ambiguous',
#   'needing',
#   'editing',
#   'quora',
#   'theyre',
#   'fine'],
#  ['every', 'last', 'name', 'see', 'male', 'name'],
#  ['arabs', 'hate', 'iranians'],
#  ['suitable',
#   'inpatient',
#   'drug',
#   'alcohol',
#   'rehab',
#   'center',
#   'near',
#   'coweta',
#   'county',
#   'ga'],
#  ['saber', 'tooth', 'tigers', 'differ', 'lions'],
#  ['guys', 'last', 'long', 'sex'],
#  ['best', 'seo', 'company', 'delhi', 'india'],
#  ['carbon', 'finance'],
#  ['best', 'institute', 'php', 'training'],
#  ['quorans',
#   'ask',
#   'simple',
#   'factual',
#   'questions',
#   'answered',
#   'single',
#   'search',
#   'google'],
#  ['start', 'poetry', 'slam', 'library'],
#  ['delete', 'anonymous', 'question', 'quora', 'account'],
#  ['hotel',
#   'khalilabad',
#   'would',
#   'safe',
#   'unmarried',
#   'couples',
#   'without',
#   'harassment',
#   'police',
#   'hotel',
#   'staff',
#   'moral',
#   'police'],
#  ['long', 'venmo', 'transfers', 'take'],
#  ['get', 'free', 'hulu', 'account'],
#  ['best', 'framework', 'designing', 'software'],
#  ['type', 'jellyfishes', 'sting', 'treat', 'stung', 'person'],
#  ['happens', 'ptsd', 'flashback'],
#  ['buy', 'laptop', 'online', 'store', 'nearby', 'market'],
#  ['i5', '6400', 'bottleneck', 'gtx', '1070'],
#  ['imessage', 'isnt', 'saying', 'delivered', 'blocked', 'ios', '10'],
#  ['best', 'tutorialsbooks', 'learning', 'openui5sapui5'],
#  ['fight', 'ocd'],
#  ['dialogue', 'writing'],
#  ['mean', 'every', 'time', 'look', 'clock', 'numbers'],
#  ['apple', 'expensive'],
#  ['hindu', 'view', 'homosexuality'],
#  ['best', 'approach', 'responding', 'unsolicited', 'job', 'inquiries'],
#  ['best', 'language', 'network', 'programming'],
#  ['jk', 'rowling', 'donate', 'money'],
#  ['steam',
#   'turbine',
#   'condensed',
#   'water',
#   'converted',
#   'steam',
#   'run',
#   'turbine',
#   'cant',
#   'super',
#   'heat',
#   'lower',
#   'temp',
#   'steam',
#   'run',
#   'turbine',
#   'power',
#   'plants'],
#  ['police',
#   'officerofficers',
#   'lieutenant',
#   'captain',
#   'commissioner',
#   'etc',
#   'actually',
#   'commissioned',
#   'like',
#   'military',
#   'counterparts'],
#  ['real', 'life', 'examples', 'karma'],
#  ['indians', 'think', 'hillary', 'clinton'],
#  ['word', 'twihard', 'coined'],
#  ['mean', 'angular', 'momentum'],
#  ['energy',
#   'borrowed',
#   'vacuumto',
#   'returned',
#   'immediately',
#   'happens',
#   'know',
#   'vacuum',
#   'energy',
#   'real',
#   'virtual',
#   'particles',
#   'dont',
#   'exist'],
#  ['expiry', 'date', 'currency', 'notes'],
#  ['best', 'online', 'ios', 'android', 'development', 'courses'],
#  ['quora', 'users', 'left', 'wing', 'progressives'],
#  ['quantcast',
#   'dropped',
#   'demographic',
#   'data',
#   'bunch',
#   'sites',
#   'way',
#   'view',
#   'demographics',
#   'paid',
#   'account',
#   'permanently',
#   'gone'],
#  ['many', 'fallen', 'love', 'monica', 'belluci', 'watching', 'malena'],
#  ['purpose', 'rectangle', 'pentagon', 'compass', 'surveying'],
#  ['stop', 'procrastinating', 'facebook'],
#  ['best', 'new', 'camping', 'gadgets', 'people', 'dont', 'know'],
#  ['websites', 'visit', 'daily'],
#  ['inspirational', 'books', 'ever', 'read', 'get', 'inspired'],
#  ['cool', 'things', 'outside', 'friends'],
#  ['lucifer', 'gabrielle', 'relate'],
#  ['beautiful', 'flag', 'world'],
#  ['pell', 'grant', 'refunds', 'work'],
#  ['stops', 'people', 'life'],
#  ['recover', 'gmail', 'password'],
#  ['would', 'hitler'],
#  ['wwe', 'superstar', 'john', 'cena'],
#  ['competitive', 'hiring', 'process', 'proassurance'],
#  ['beta', 'tester'],
#  ['best', 'travel', 'destinations', 'photograps'],
#  ['think', 'table', 'manners', 'china', 'western', 'coutries'],
#  ['testing', 'production', 'concept'],
#  ['quebec', 'city', 'conservative'],
#  ['major', 'social', 'faux', 'avoid', 'visiting', 'nigeria'],
#  ['block', 'user', 'answering', 'questions'],
#  ['long', 'take', 'fluently', 'speak', 'language'],
#  ['important', 'life', '', 'money', 'values'],
#  ['difference', 'direct', 'indirect', 'elections'],
#  ['taiwan',
#   'hold',
#   'referendum',
#   'break',
#   'free',
#   'china',
#   'become',
#   'sovereign',
#   'state'],
#  ['much',
#   'time',
#   'take',
#   'hens',
#   'dominate',
#   'earth',
#   'eggs',
#   'eaten',
#   'humans'],
#  ['best', 'quickbooks', 'tech', 'support', 'number', 'north', 'dakota'],
#  ['examples', 'homozygous', 'dominant', 'homozygous', 'recessive', 'genes'],
#  ['common', 'lies', 'told', 'software', 'developer'],
#  ['use',
#   'r',
#   'windows',
#   'work',
#   'large',
#   'data',
#   'ideal',
#   'machine',
#   'configuration'],
#  ['chance', 'world', 'iii'],
#  ['keywords', 'meta', 'tags', 'still', 'important', 'matters', 'seo'],
#  ['hackathons', 'india'],
#  ['one', 'pass', 'hair', 'folicle', 'test', 'meth', 'dirty'],
#  ['faith', 'move', 'mountains', 'even', 'god'],
#  ['billionaires', 'really', 'need', 'bodyguards'],
#  ['tips', 'making', 'job', 'interview', 'process', 'rosetta', 'resources'],
#  ['low', 'latent', 'inhibition'],
#  ['20',
#   'year',
#   'old',
#   'international',
#   'freshman',
#   'dream',
#   'university',
#   'us',
#   'ever',
#   'since',
#   'got',
#   'lost',
#   'motivation',
#   'work',
#   'hard',
#   'fun',
#   'even',
#   'advice',
#   'ive',
#   'lots',
#   'people',
#   'feel',
#   'lonely'],
#  ['palm', 'rejection', 'enabled', 'stylus', 'windows', 'tablets'],
#  ['get', 'funded', 'based', 'startup', 'idea'],
#  ['laptop',
#   'showing',
#   'limited',
#   'internet',
#   'access',
#   'home',
#   'wifi',
#   'connection'],
#  ['link', 'waves', 'circle'],
#  ['would', 'jailbreak', 'ps3'],
#  ['possible', 'start', 'fire', 'ice'],
#  ['add', 'add', 'text', 'ipythonjupyter', 'notebook'],
#  ['deactivating',
#   'axis',
#   'salary',
#   'account',
#   'account',
#   'linked',
#   'axis',
#   'credit',
#   'card',
#   'credit',
#   'card',
#   'deactivated',
#   'affected'],
#  ['could', 'donald', 'trump', 'actually', 'win', 'become', 'potus'],
#  ['days', 'week', 'based'],
#  ['make', 'free', 'calls', 'family', 'members', 'airtel', 'andhra', 'pradesh'],
#  ['future', 'tomorrow'],
#  ['could',
#   'light',
#   'refracted',
#   'loop',
#   'amplified',
#   'stored',
#   'source',
#   'potential',
#   'energy'],
#  ['america',
#   'nuclear',
#   'weapons',
#   'isnt',
#   'threat',
#   'despite',
#   'fact',
#   'america',
#   'country',
#   'use',
#   'weapons',
#   'twice',
#   'anger'],
#  ['support',
#   'among',
#   'lowincome',
#   'democratic',
#   'voters',
#   'clinton',
#   'sanders'],
#  ['mechanical',
#   'engineering',
#   'student',
#   'work',
#   'software',
#   'mnc',
#   'chance',
#   'get',
#   'mechanical',
#   'field',
#   'working',
#   'mech',
#   'grads'],
#  ['makes', 'javascript', 'jquery'],
#  ['great', 'examples', 'presence', 'mind'],
#  ['dark', 'ages', 'really', 'pretty', 'dark'],
#  ['favorite', 'mindsoothing', 'english', 'songs'],
#  ['best', 'water', 'technology', 'drinking'],
#  ['significance', 'technology', 'event', 'management', 'decoration'],
#  ['donald', 'trump', 'still', 'win', 'election'],
#  ['purpose', 'education'],
#  ['value', 'currency', 'fall'],
#  ['best', 'brand', 'cigarette'],
#  ['africa', 'rich', 'poor'],
#  ['control', 'anger'],
#  ['spirit', 'coach'],
#  ['late', 'learn', 'programming', '40'],
#  ['arnab', 'goswami', 'resign', 'editorinchief', 'times'],
#  ['time', 'physical', 'dimension'],
#  ['like',
#   'flying',
#   'bangkok',
#   'manila',
#   'touristic',
#   'cities',
#   'compared',
#   'kolkata'],
#  ['often', 'change', 'aircraft', 'tires'],
#  ['selftaught',
#   'uiux',
#   'designer',
#   'india',
#   'journey',
#   'getting',
#   'first',
#   'entrylevel',
#   'job'],
#  ['upgrade', 'intex', 'aqua', 'power', 'lolipop'],
#  ['donald', 'trump', 'actually', 'president'],
#  ['people', 'think', 'eve', 'online', 'best', 'mmo'],
#  ['set', 'belkin', 'n300', 'wireless', 'modem', 'router'],
#  ['education', 'kills', 'creativity'],
#  ['children', 'young', 'adults', 'learn', 'elders'],
#  ['jio', 'sim', 'work', 'galaxy', 's3'],
#  ['find', 'hacker'],
#  ['richest', 'world'],
#  ['purported', 'magic', 'trickillusion', 'put', 'together'],
#  ['chinese', 'encroach', 'whole', 'word'],
#  ['sanitizer', 'work'],
#  ['best', 'ways', 'improve', 'intelligence'],
#  ['many', 'stories', 'inside', 'unable', 'write', 'paper', 'passionwhat'],
#  ['questionasking', 'websites', 'like', 'quora'],
#  ['know', 'move'],
#  ['become', 'digital', 'marketing', 'expert'],
#  ['app', 'allows', 'listen', 'music', 'without', 'wifi', 'internet'],
#  ['realize', 'youve', 'grown'],
#  ['east',
#   'asian',
#   'south',
#   'southeast',
#   'asian',
#   'countrys',
#   'women',
#   'open',
#   'relationship',
#   'western',
#   'caucasian',
#   'male'],
#  ['solution', 'google', 'stop', 'spam', 'calls'],
#  ['set', 'number', 'google', 'voice'],
#  ['sharing', 'comb', 'spread', 'grey', 'hair'],
#  ['people', 'claim', 'death', 'lethal', 'injection', 'painful'],
#  ['shoot', 'something', 'space', 'rail', 'gun'],
#  ['embarrassing', 'thing', 'happened', 'front', 'boss'],
#  ['bring', 'product', 'idea', 'reality'],
#  ['towns',
#   'located',
#   'near',
#   'kilauea',
#   'volcanos',
#   'activity',
#   'compare',
#   'volcanoes',
#   'china'],
#  ['really', 'secret', 'success'],
#  ['united', 'city', 'fans', 'manchester'],
#  ['abandonment', 'property', 'law', 'created', 'philadelphia', 'pa'],
#  ['hard',
#   'question',
#   'think',
#   'becoming',
#   'billionaire',
#   'meant',
#   'select',
#   'like',
#   'actors',
#   'singers',
#   'pro',
#   'athletes',
#   '1',
#   'percent',
#   'makes'],
#  ['best', 'books', 'preparation', 'gate', 'examme'],
#  ['sell',
#   'sonic',
#   'toothbrush',
#   'subscription',
#   '399',
#   'month',
#   'replace',
#   'breaks',
#   'supply',
#   'brush',
#   'heads',
#   'buy'],
#  ['think', 'humpty', 'dumpty', 'egg', 'rhyme', 'makes', 'reference', 'fact'],
#  ['help', 'someone', 'undergoing', 'complicated', 'mourning'],
#  ['survive', 'corporate', 'world'],
#  ['would', 'isps', 'block', 'forums', 'without', 'net', 'neutrality'],
#  ['kuznyechik', 'encryption', 'unsafe'],
#  ['best', 'pictures', 'showcase', 'life'],
#  ['lose', 'weight', 'loss'],
#  ['endocytosis', 'exocytosis', 'differ'],
#  ['blind',
#   'asked',
#   'draw',
#   'thought',
#   'logo',
#   'insert',
#   'popular',
#   'brand',
#   'might',
#   'look',
#   'like',
#   'would',
#   'draw'],
#  ['conditions', 'refraction', 'light'],
#  ['think', 'modi', 'government', 'decision', 'ban', '5001000', 'notes'],
#  ['things', 'new', 'employees', 'know', 'going', 'first', 'day', 'seaboard'],
#  ['detect', 'mobile', 'spyware'],
#  ['way', 'separate', 'nitrogen', 'exhaust', 'gases'],
#  ['gravitational', 'waves', 'laymens', 'terms'],
#  ['best', 'regards', 'kind', 'regards', 'considered', 'bad', 'english'],
#  ['someone', 'asks', 'question', 'answer', 'say'],
#  ['acceptable',
#   '17',
#   'year',
#   'old',
#   'high',
#   'school',
#   'junior',
#   'date',
#   '14',
#   'year',
#   'old',
#   'high',
#   'school',
#   'sophomore'],
#  ['difference', 'electron', 'affinity', 'electron', 'gain', 'enthalpy'],
#  ['would',
#   'happen',
#   'probable',
#   'email',
#   'addresses',
#   'taken',
#   'due',
#   'increase',
#   'users'],
#  ['quora', 'banned', 'real', 'name', 'account', 'fake'],
#  ['less', '100', 'followers', 'instagram'],
#  ['best', 'moment', 'life', 'dearest', 'one'],
#  ['germany', 'defeat', 'france', 'quickly', '1940'],
#  ['wll', 'get', 'marshmallow', 'update', 'asus', 'zenfone', '2', 'lazer'],
#  ['identify', 'originality', 'rayban', 'sunglasses'],
#  ['true', 'rs', '2000', 'note', 'india', 'embedded', 'ngc', 'chips'],
#  ['prepare', 'income', 'tax', 'officers', 'exam'],
#  ['soul', 'satisfying', 'thing', 'ever', 'done', 'life'],
#  ['people',
#   'ask',
#   'questions',
#   'quora',
#   'easily',
#   'find',
#   'answers',
#   'google'],
#  ['develop', 'app'],
#  ['ground', 'water'],
#  ['prepare', 'coding', 'interview'],
#  ['wake', 'early', 'staying', 'late'],
#  ['girl', 'sex', 'boy'],
#  ['person', 'love', 'two', 'persons', 'time'],
#  ['sahara',
#   'average',
#   'temperatures',
#   'compare',
#   'ones',
#   'great',
#   'victoria',
#   'desert'],
#  ['best', 'way', 'reduce', 'belly', 'arm', 'fat'],
#  ['factory', 'reset', 'toshiba', 'satellite', 'laptop'],
#  ['board',
#   'marks',
#   'taken',
#   'account',
#   '2017',
#   'many',
#   'marks',
#   'need',
#   'get',
#   'jee',
#   'mains',
#   'get',
#   'cselectrical',
#   'nsit',
#   'dtu'],
#  ['prepare', 'ias', 'mains', 'paper', '3'],
#  ['free',
#   'ddns',
#   'supplier',
#   'uses',
#   'tsig',
#   'without',
#   'requiring',
#   'installation',
#   'client',
#   'pc',
#   'locally'],
#  ['surgical', 'strike'],
#  ['global', 'small', 'everyday', 'problems', 'waiting', 'solved'],
#  ['many', 'states', 'india', 'time', 'independence'],
#  ['difference', 'nonbinary', 'ternary', 'compounds'],
#  ['get', 'rid', 'ant', 'problems', 'house'],
#  ['one', 'thing', 'life'],
#  ['gate', 'held', 'apply'],
#  ['us', 'constitution', 'amended', 'officially'],
#  ['goals', 'profit', 'maximization', 'examples'],
#  ['bears', 'expenses', 'saarc', 'summit', 'host', 'country', 'organization'],
#  ['nice', 'places', 'readwork', 'late', 'night', 'manhattan'],
#  ['neighborhood', 'good', 'utrecht'],
#  ['need', 'start', 'business'],
#  ['us', 'passport', 'number', 'social', 'security', 'number'],
#  ['whats', 'resolutions', '2017'],
#  ['open', 'z01', 'file'],
#  ['depression'],
#  ['make', 'money', 'making', 'icons'],
#  ['best', 'programming', 'language', 'know'],
#  ['requirements', 'get', 'german', 'university'],
#  ['improve', 'thought', 'quality'],
#  ['best', 'doctor', 'episode', 'get', 'someone', 'addicted', 'series'],
#  ['green', 'tea', 'really', 'reduces', 'weight'],
#  ['theoretically', 'possible', 'travel', 'parallel', 'universe'],
#  ['give', 'mother', 'birthday'],
#  ['wish', 'someone', 'happy', 'birthday', 'latin'],
#  ['public', 'welfare', 'campaign'],
#  ['keep', 'awake', 'boring', 'lectures'],
#  ['perform', 'reverse', 'engineering', 'pharmaceuticals'],
#  ['different', 'terrestrial', 'animals', 'live', 'adapt', 'enviroment'],
#  ['become', 'modern'],
#  ['chr6coxhap2', 'mean'],
#  ['filter',
#   'questions',
#   'quora',
#   'feed',
#   'contain',
#   'either',
#   'words',
#   'atheist',
#   'obama'],
#  ['unknown', 'facts', 'bollywood'],
#  ['possible', 'fall', 'love', 'someone', 'never'],
#  ['buy', 'macbook', 'apples', 'student', 'discount'],
#  ['pets', 'ever', 'commit', 'suicide'],
#  ['anal', 'sex'],
#  ['need', 'produce', 'tea'],
#  ['syrians', 'running', 'away', 'isis'],
#  ['consciousness',
#   'result',
#   'electrical',
#   'feedback',
#   'loop',
#   'nervous',
#   'system'],
#  ['first', 'orgasm'],
#  ['frequent', 'one', 'sex'],
#  ['typography', 'typeface', 'identification', 'font', 'fiat', 'logo', 'based'],
#  ['nyquil', 'cause', 'drowsiness'],
#  ['scary', 'horror', 'stories'],
#  ['become', 'topper', 'engineering'],
#  ['difference', 'jerk', 'asshole'],
#  ['americium', 'classified'],
#  ['court',
#   'marriage',
#   'acceptable',
#   'document',
#   'canadian',
#   'visa',
#   'c12',
#   'dependent'],
#  ['dont',
#   'feel',
#   'confident',
#   'crack',
#   'gate',
#   'done',
#   '50',
#   'course',
#   'feel',
#   'demotivated'],
#  ['hand',
#   'salary',
#   'central',
#   'government',
#   'e3',
#   'level',
#   'job',
#   'pay',
#   'scale',
#   'rs',
#   '2910054500',
#   'ida'],
#  ['logout', 'quora'],
#  ['possibilities',
#   'nuclear',
#   'india',
#   'pakistan',
#   'surgical',
#   'strike',
#   'attack',
#   'pok'],
#  ['buy',
#   'vilain',
#   'hair',
#   'wax',
#   'products',
#   'costs',
#   'around',
#   '20',
#   '',
#   'ship',
#   'india',
#   'denmark',
#   'pay',
#   'custom',
#   'duty'],
#  ['solve',
#   'black',
#   'screen',
#   'bug',
#   'lumia',
#   '720',
#   'phone',
#   'actually',
#   'working',
#   'condition',
#   'nothing',
#   'displayed',
#   'screen'],
#  ['replacement',
#   '5001000',
#   'rupee',
#   'notes',
#   '5002000',
#   'rupee',
#   'notes',
#   'panacea',
#   'corruption'],
#  ['best', 'digital', 'marketing', 'company', 'chandigarh'],
#  ['language', 'best', 'coding'],
#  ['best', 'birthday', 'gift', 'friend'],
#  ['spy', 'snapchat', 'samsung'],
#  ['could',
#   'lady',
#   'shiva',
#   'defeat',
#   'lung',
#   'kung',
#   'panda',
#   'fight',
#   'death'],
#  ['dangerous', 'places', 'stay', 'world', 'places', 'dangerous'],
#  ['indians', 'think', 'sri', 'lanka'],
#  ['segmental', 'movements', 'differ', 'peristaltic', 'movements'],
#  ['best', 'shahrukh', 'khan', 'movies'],
#  ['programming', 'language', 'needed', 'google', 'code', 'jam'],
#  ['difference', 'usb', '30', 'usb', '20'],
#  ['divorce', 'rate', 'high', 'among', 'americans'],
#  ['dth', 'service', 'india', 'best', 'hd', 'channels'],
#  ['favourite', 'bible', 'verse'],
#  ['look', 'forward'],
#  ['petroleum', 'jelly', 'help', 'eyelashes', 'grow'],
#  ['godfather',
#   'part',
#   '1974',
#   'movie',
#   'right',
#   'wrong',
#   'beef',
#   'frank',
#   'pentangelli',
#   'rosato',
#   'brothers'],
#  ['bad', 'swallow', 'bleach'],
#  ['wizard', 'propel', 'spaceships'],
#  ['iconic', 'images', 'medicine'],
#  ['whats', 'difference', 'milf', 'cougar'],
#  ['team',
#   'india',
#   'cricket',
#   'wins',
#   'match',
#   'series',
#   'get',
#   'paid',
#   'usual',
#   'fixed',
#   'salaries'],
#  ['currently',
#   'pursuing',
#   'mba',
#   'would',
#   'like',
#   'make',
#   'career',
#   'field',
#   'digital',
#   'marketing',
#   'certifications',
#   'courses',
#   'differentiate',
#   'resume',
#   'freshers'],
#  ['universities',
#   'methode',
#   'electronics',
#   'recruit',
#   'new',
#   'grads',
#   'majors',
#   'looking'],
#  ['leonardo', 'dicaprio', 'yacht', 'given', 'climate', 'change', 'advocacy'],
#  ['israel',
#   'able',
#   'win',
#   'arabisraeli',
#   '1948',
#   'standing',
#   'alone',
#   'alliance',
#   'five',
#   'arab',
#   'states',
#   'victory',
#   'odds'],
#  ['would',
#   'happen',
#   'someday',
#   'people',
#   'bombed',
#   'moon',
#   'moon',
#   'disappears'],
#  ['function', 'epithelial', 'tissue', 'heart'],
#  ['whats', 'best', 'oneplayer', 'card', 'game'],
#  ['account',
#   'sbi',
#   'bank',
#   'withdraw',
#   'money',
#   'different',
#   'branches',
#   'across',
#   'india'],
#  ['best', 'raid', 'configuration', 'media', 'center', 'pc'],
#  ['calculate', 'spring', 'stiffness', 'front', 'suspension'],
#  ['best', 'place', 'meet', 'hot', 'women', 'san', 'francisco'],
#  ['universe', 'born'],
#  ['country', 'never', 'colonized', 'power'],
#  ['free', 'font', 'brush', 'management', 'tools', 'photoshop', 'cs5'],
#  ['kolkata', 'rated'],
#  ['best', 'gate', 'coaching', 'csit', 'indore'],
#  ['proven', 'souls'],
#  ['best', 'nootropics', 'social', 'anxiety'],
#  ['prepare',
#   'barc',
#   'interview',
#   'mechanical',
#   'engineering',
#   'month',
#   'prepare'],
#  ['would',
#   'better',
#   'single',
#   'entity',
#   'put',
#   'fiscal',
#   'monetary',
#   'policies'],
#  ['suggestions', 'good', 'music'],
#  ['often',
#   'see',
#   'young',
#   'aspirant',
#   'wants',
#   'great',
#   'things',
#   'nation',
#   'society',
#   'merely',
#   'ends',
#   'small',
#   'things',
#   'graduating'],
#  ['get', 'girl', 'back', 'breakup'],
#  ['time', 'walmart', 'money', 'center', 'close'],
#  ['use', 'upi', 'system', 'make', 'transaction'],
#  ['martin', 'luther', 'king', 'jrs', 'iq'],
#  ['best', 'way', 'flush', 'methamphetamines', 'system'],
#  ['expect', 'suzuki', 'gixxer', 'sf'],
#  ['know', 'partner', 'cheating'],
#  ['steve', 'jobs', 'mentor'],
#  ['questions', 'answer'],
#  ['black', 'hole', 'hole', 'spacetime', 'deep', 'curvature', 'spacetime'],
#  ['signs', 'symptoms', 'need', 'salt', 'body'],
#  ['stupid', 'question', 'asked', 'quora'],
#  ['oxygen', 'laser', 'therapy', 'effective'],
#  ['best', 'car', 'give', 'ola', 'cab'],
#  ['know', 'someone', 'got', 'messaged', 'texted', 'blocked'],
#  ['favourite', 'song'],
#  ['taylor', 'swift', 'overrated'],
#  ['best', 'regards', 'kind', 'regards', 'considered', 'bad', 'english'],
#  ['safest', 'places', 'live'],
#  ['difference', 'high', 'school', 'secondary', 'school', 'public', 'school'],
#  ['exercise', 'bad', 'diabetics'],
#  ['provision', 'go', 'supreme', 'court', 'parliamentary', 'privileges'],
#  ['suitable',
#   'inpatient',
#   'drug',
#   'alcohol',
#   'rehab',
#   'center',
#   'washington',
#   'county',
#   'id'],
#  ['use',
#   'mtk',
#   'engineering',
#   'mode',
#   'app',
#   'available',
#   'playstore',
#   'know',
#   'increase',
#   'soundbut',
#   'many',
#   'features',
#   'app'],
#  ['delete', 'auto', 'backup', 'photos', 'gallery', 'samsung', 'note', '2'],
#  ['relationship', 'socrates', 'plato', 'aristotle'],
#  ['reservation', 'system', 'overthrown', 'india'],
#  ['social', 'trade'],
#  ['world', '3', 'way', 'us', 'elections'],
#  ['electrons', 'revolve', 'around', 'nucleus'],
#  ['like', 'cia', 'spy'],
#  ['actors', 'get', 'naked', 'movies', 'real', 'cinematographical', 'gimmick'],
#  ['steal',
#   'wifi',
#   'password',
#   'creating',
#   'fake',
#   'access',
#   'point',
#   'similar',
#   'name',
#   'original',
#   'one'],
#  ['us', 'president', 'removed', 'office'],
#  ['find', 'song', 'list', 'victorious'],
#  ['time', 'dilation'],
#  ['reaction', 'atp', '', 'adp', '', 'p', 'occur'],
#  ['harry',
#   'potter',
#   'rightful',
#   'owner',
#   'elder',
#   'wand',
#   'destroy',
#   'harry',
#   'potter',
#   'deathly',
#   'hallows',
#   'part',
#   '2'],
#  ['milk', 'bad', 'health'],
#  ['best', 'laptop', '30', 'k', 'personal', 'use'],
#  ['romantic', 'poem', 'ever', 'written'],
#  ['geolocate', 'sim', 'card'],
#  ['best', 'site', 'download', 'tv', 'series', 'torrents'],
#  ['playstation', 'vita'],
#  ['one', 'overcome', 'fear', 'speaking', 'public'],
#  ['calculate', 'volume', 'circle'],
#  ['dogs', 'like', 'tear', 'innards', 'stuffed', 'animals'],
#  ['healthy', 'daily', 'activities', 'habits', 'every', 'student', 'adopt'],
#  ['make', 'hair', 'grow', 'faster'],
#  ['would', 'happen', 'immigration', 'barriers', 'lowered'],
#  ['common', 'reasons', 'breakup'],
#  ['improve', 'speaking'],
#  ['review', 'love', '2009', 'movie'],
#  ['app', 'allows', 'listen', 'music', 'without', 'wifi', 'internet'],
#  ['hack', 'doodle', 'army', '2', 'mini', 'militia', 'get', 'pro', 'version'],
#  ['google', 'indexed', 'blog', 'properly'],
#  ['best', 'gas', 'blowback', 'airsoft', 'rifle', 'considered', 'best'],
#  ['books', 'best', 'closing', 'lines'],
#  ['buy', 'iphone', 'sim', 'card'],
#  ['programming', 'languages', 'used', 'industry'],
#  ['best', 'quickbooks', 'support', 'number', 'arkansas'],
#  ['five', 'guys', 'give', 'customers', 'twice', 'amount', 'fries', 'order'],
#  ['exact', 'english', 'word', 'amavasya'],
#  ['buy', 'another', 'laptop', 'get', 'google', 'tv'],
#  ['games', 'improve', 'memory'],
#  ['whiten', 'groin', 'area'],
#  ['academic', 'pressure', 'workload', 'concordia', 'university', 'like'],
#  ['benefits', 'qualifying', 'ugc', 'net', 'exam'],
#  ['people', 'protesting', 'north', 'dakota'],
#  ['much', 'time', 'take', 'learn', 'android', 'app', 'development', 'scratch'],
#  ['telugu',
#   'made',
#   'one',
#   'official',
#   'languages',
#   'tamil',
#   'nadu',
#   'since',
#   '50',
#   'speak',
#   'telugu'],
#  ['rank', 'comedk', '2016', '1412', 'get', 'cse', 'top', 'colleges'],
#  ['best', 'career', 'options', 'completing', 'bcom'],
#  ['difference', 'cvtrack', 'cvblob'],
#  ['certain', 'people', 'stay', 'top', 'likes', 'instagram'],
#  ['diagram', 'snow', 'leopards', 'food', 'chain'],
#  ['people', 'patriotic'],
#  ['hide', 'friend', 'list', 'facebook'],
#  ['density', 'water', 'room', 'temp'],
#  ['best', 'iphone', 'app'],
#  ['tv', 'channel', 'earn', 'money'],
#  ['lewis', 'structure', 'h2co3', 'determined'],
#  ['place', 'better', 'live', 'family', 'australia', 'canada'],
#  ['would', 'change', 'quora'],
#  ['describe', 'player', 'one', 'picture', 'would'],
#  ['banking', 'meant', 'account', 'cycling'],
#  ['bollywood', 'actress', 'perfect', 'boobs'],
#  ['hillary', 'clintons', 'health', 'affect', 'election'],
#  ['code', 'conduct', 'mean'],
#  ['time', 'measured', 'another', 'unit', 'hours', 'minutes', 'seconds'],
#  ['address', 'send', 'application', 'officer', 'entry', 'indian', 'navy'],
#  ['hillary', 'clinton', 'stands'],
#  ['like', 'love', 'gold', 'digger'],
#  ['anyone', 'solution', 'moto', 'g', 'auto', 'switching'],
#  ['feeding', 'habits', 'qatar', 'people'],
#  ['make', 'money', 'online', 'job'],
#  ['rightmove',
#   'zoopla',
#   'prime',
#   'location',
#   'get',
#   'list',
#   'towns',
#   'cities',
#   'coordinates',
#   'boundaries',
#   'buying',
#   'somewhere',
#   'publicly',
#   'available'],
#  ['tell', 'someone', 'psychopath'],
#  ['long', 'distance', 'relationship', 'work'],
#  ['give', 'root', 'access', 'xmodgames', 'without', 'rooting'],
#  ['happens',
#   'mark',
#   'notifications',
#   'read',
#   'delete',
#   'individual',
#   'notices'],
#  ['agrees',
#   'question',
#   'answer',
#   'stuff',
#   'needs',
#   'improvement',
#   'load',
#   'crap'],
#  ['find', 'angel', 'investors', 'startup', 'idea', 'vizag', 'city'],
#  ['tell', 'best', 'friend', 'love'],
#  ['percentile', 'calculated'],
#  ['500',
#   'trillion',
#   'rich',
#   'rothschilds',
#   'forbes',
#   'richest',
#   'people',
#   'list'],
#  ['democrats',
#   'favor',
#   'obama',
#   'releasing',
#   'converted',
#   'criminals',
#   'theres',
#   'risk',
#   'families'],
#  ['criticisms', 'fair', 'trade'],
#  ['steve', 'ballmer', 'become', 'ceo', 'microsoft'],
#  ['labor',
#   'unions',
#   'become',
#   'intertwined',
#   'organized',
#   'crime',
#   'like',
#   'mafia'],
#  ['mean',
#   'someone',
#   'views',
#   'profile',
#   'linkedin',
#   'linkedin',
#   'lists',
#   'viewed',
#   'homepage'],
#  ['comes',
#   'year',
#   'twice',
#   'month',
#   '4',
#   'times',
#   'week',
#   '6',
#   'times',
#   'day'],
#  ['address', 'two', 'people', 'business', 'letter'],
#  ['best', 'ways', 'prepare', 'class', '10th', 'board', 'exam', 'cbse'],
#  ['nonfoliated', 'rock'],
#  ['facts', 'switzerland', 'rest', 'world', 'doesnt', 'know'],
#  ['new', 'quora', 'font', 'august', '16', '2016'],
#  ['find',
#   'undervalued',
#   'stocks',
#   'indian',
#   'stock',
#   'market',
#   'basic',
#   'examples'],
#  ['best', 'way', 'calm', 'mind'],
#  ['best',
#   'institutes',
#   'deploma',
#   'public',
#   'health',
#   'west',
#   'bengal',
#   'admission',
#   'criteria'],
#  ['determine', 'lewis', 'dot', 'structure', 'sulfur', 'trioxide'],
#  ['see', 'future'],
#  ['research', 'topics', 'cyber', 'security'],
#  ['challenging',
#   'encompass',
#   'snmp',
#   'active',
#   'measurement',
#   'platform',
#   'give',
#   'reference',
#   'literature',
#   'proves'],
#  ['bassists', 'use', 'picks'],
#  ['improve', 'english', 'writing', 'skills'],
#  ['best', 'restaurants', 'near', 'eastern', 'universitys', 'campus'],
#  ['diseases', 'rats', 'cause', 'ww1'],
#  ['swiss', 'challenge'],
#  ['find', 'old', 'gmail', 'accounts'],
#  ['normal', 'watery', 'discharge'],
#  ['hairstyles', 'vikings'],
#  ['josé', 'mourinho', 'manchester', 'united'],
#  ['best', 'ways', 'learn', 'financial', 'modeling'],
#  ['get', 'blue', 'verification', 'quora'],
#  ['makes', 'someone', 'happy'],
#  ['magnetic', 'field', 'produce', 'current', 'flows', 'conductor'],
#  ['earn', 'money', 'online'],
#  ['causes', 'extreme', 'cases', 'hoarding'],
#  ['hard', 'self', 'teach', 'ukulele'],
#  ['freeze', 'pudding', 'pie'],
#  ['history',
#   'glassboro',
#   'train',
#   'station',
#   'compare',
#   'burswood',
#   'station'],
#  ['structure', 'veins', 'arteries', 'relate', 'function'],
#  ['good', 'pay', 'credit', 'card', 'payment', 'full', 'month'],
#  ['review', 'run', '2011', 'movie'],
#  ['easy', 'way', 'memorise', 'periodic', 'table'],
#  ['technologies', 'countries', 'developed', 'indians', 'dont', 'know'],
#  ['yif', 'call', 'telephonic', 'interview', 'day', 'given', 'date'],
#  ['cover', 'designed', 'ebook'],
#  ['girl', 'get', 'pregnant', 'last', 'day', 'periods'],
#  ['see', 'direct', 'messages', 'instagram', 'app', 'entirety', 'reliably'],
#  ['become', 'lawyer', 'bollywood'],
#  ['tweet', 'embedded', 'youtube', 'videos', 'autoplay', 'twitter'],
#  ['make', 'car'],
#  ['onsite', 'relocation', 'policy', 'wipro'],
#  ['good', 'online', 'resource', 'learning', 'django', 'quickly'],
#  ['view', 'pictures', 'instagram', 'without', 'account'],
#  ['brush', 'teeth', 'breakfast'],
#  ['saltwater', 'taffy', 'candy', 'imported', 'bahamas'],
#  ['cost',
#   'comparison',
#   'alternative',
#   'energy',
#   'development',
#   'vs',
#   'going',
#   'iraq'],
#  ['best', 'laptop', 'coding'],
#  ['crop', 'circles', 'made'],
#  ['skip', 'abominable', 'bride', 'watch', 'season', '4'],
#  ['would', 'happen', 'united', 'states', 'russia', 'went'],
#  ['major', 'types', 'volcanoes', 'differ'],
#  ['applications', 'full', 'adder', 'circuit'],
#  ['could',
#   'pick',
#   'move',
#   'right',
#   'live',
#   'anywhere',
#   'world',
#   'would',
#   'live'],
#  ['recommended',
#   'daily',
#   'values',
#   'micronutrients',
#   'say',
#   '110',
#   'lb',
#   'woman',
#   '200',
#   'lb',
#   'like',
#   'macros'],
#  ['total',
#   'cost',
#   'three',
#   'books',
#   'four',
#   'pens',
#   'rs',
#   '520',
#   'cost',
#   'one',
#   'book',
#   'twice',
#   'much',
#   'pen',
#   'cost',
#   'one',
#   'pen'],
#  ['quora', 'better', 'facebook', 'twitter'],
#  ['best', 'book', 'mpmc'],
#  ['proper', 'etiquette', 'someone', 'buys', 'shot', 'bar'],
#  ['hannibal', 'ask', 'senator', 'breastfed'],
#  ['important', 'life'],
#  ['difference', 'saying', 'love', 'love'],
#  ['state', 'journalism', 'today'],
#  ['overcome', 'insomnia'],
#  ['lesser',
#   'known',
#   'important',
#   'historical',
#   'figures',
#   'cyprus',
#   'people',
#   'know'],
#  ['vacuum', 'energy', 'infinite'],
#  ['full',
#   'wave',
#   'bridge',
#   'rectifier',
#   'better',
#   'full',
#   'wave',
#   'centre',
#   'tap',
#   'rectifier'],
#  ['best', 'way', 'learn', 'touch', 'typing'],
#  ['ever', 'lied', 'quora'],
#  ['way', 'overcome', 'stage', 'fear'],
#  ['guy', 'picture'],
#  ['equipotential', 'bonding', 'zones', 'electricity'],
#  ['fifa',
#   '17',
#   'played',
#   'intel',
#   'iris',
#   'graphics',
#   '6100',
#   '1536',
#   'mb',
#   'graphics',
#   'card',
#   'i5',
#   'processor',
#   'mac',
#   'book',
#   'pro',
#   'windows',
#   '10'],
#  ['many', 'incredible', 'female', 'singers', '90s'],
#  ['world', 'bank'],
#  ['every', 'youtube', 'star'],
#  ['calculate',
#   'ph',
#   '01',
#   'nacn',
#   'solution',
#   'ka',
#   'hcn',
#   '41010',
#   '',
#   'request'],
#  ['set', 'entity', 'business'],
#  ['conspiracy', 'theories', 'later', 'proved', 'true'],
#  ['like', 'hate', 'strongly', 'dislike', 'brother', 'sister'],
#  ['learn', 'blog'],
#  ['ways', 'agriculture', 'farming', 'affect', 'environment'],
#  ['domain',
#   'name',
#   'bluehost',
#   'ive',
#   'paid',
#   'hosting',
#   'host',
#   'domain',
#   'free',
#   'host',
#   'services',
#   'like',
#   'freehostingcom'],
#  ['humans', 'go', 'extinct'],
#  ['younger', 'girls', 'like', 'older', 'guys'],
#  ['snap', 'chat', 'automatically', 'add', 'people', 'contact', 'list'],
#  ['best',
#   'implementing',
#   'cisco',
#   'secure',
#   'access',
#   'solutions',
#   'online',
#   'training'],
#  ['strong',
#   'sciatic',
#   'andor',
#   'knee',
#   'pain',
#   'stop',
#   'hitting',
#   'brakes',
#   'driving',
#   'emergency'],
#  ['buy', 'lego', 'transformers', 'options'],
#  ['forgotten', 'facebook', 'password', 'email', 'password'],
#  ['deal', 'damn', 'clowns'],
#  ['improve', 'google', 'chrome'],
#  ['possible', 'increase', 'height', '20'],
#  ['nude', 'beaches', 'punta', 'cana', 'compare', 'nude', 'beaches', 'cuba'],
#  ['audio', 'quality', 'scale', 'video', 'quality', 'youtube'],
#  ['get', 'quality', 'assistance', 'sydney', 'property', 'transaction'],
#  ['storage', 'wars', 'cancelled'],
#  ['hotel',
#   'kakkabe',
#   'hillstation',
#   'would',
#   'safe',
#   'unmarried',
#   'couples',
#   'without',
#   'harassment',
#   'police',
#   'hotel',
#   'staff',
#   'moral',
#   'police'],
#  ['name', 'mean'],
#  ['best', 'analytics', 'institute', 'bangalore', 'placement', 'support'],
#  ['top', 'universities', 'masters', 'civil', 'engineering', 'germany'],
#  ['best', 'free', 'online', 'resources', 'learning', 'german'],
#  ['ways', 'kill', 'boredom'],
#  ['dont', 'airliners', 'ejection', 'seats', 'passengers', 'crew'],
#  ['one',
#   'better',
#   'mba',
#   'option',
#   'rotman',
#   'toronto',
#   'schulich',
#   'york',
#   'uni',
#   'canada'],
#  ['laser', 'eye', 'surgery', 'safe'],
#  ['indian', 'caste', 'system', 'work'],
#  ['differences', 'sociology', 'philosophy'],
#  ['antigun',
#   'advocates',
#   'live',
#   'given',
#   'crimes',
#   'prevented',
#   'armed',
#   'citizens',
#   'unarmed',
#   'murder',
#   'victims'],
#  ['would',
#   'native',
#   'american',
#   'cultures',
#   'likely',
#   'developed',
#   'europeans',
#   'never',
#   'arrived',
#   'new',
#   'world'],
#  ['way', 'exercise', 'without', 'gaining', 'muscle'],
#  ['death', 'occur'],
#  ['best', 'tinder', 'hacks'],
#  ['main', 'difference', 'jews', 'muslims'],
#  ['many', 'accidents', 'i880'],
#  ['roger', 'goodell', 'role', 'deflategate', 'scandal'],
#  ['connect', 'motorola', 'moto', 'g', '2nd', 'gen', 'lg', 'smart', 'tv'],
#  ['books', 'resources', 'read', 'learn', 'tape', 'reading'],
#  ['ban',
#   'old',
#   '500',
#   '1000',
#   'rs',
#   'notes',
#   'help',
#   'bringing',
#   'black',
#   'money'],
#  ['one', 'crack', 'job', 'interview'],
#  ['get', 'new', 'religion', 'invented', 'ground'],
#  ['best', 'kannada', 'movies', 'time'],
#  ['magnesium', 'considered', 'solid', 'liquid', 'gas'],
#  ['coding', 'computer', 'program'],
#  ['better', 'cell', 'phone', 'tablet'],
#  ['top', 'startups', 'india'],
#  ['country', 'friendliest'],
#  ['role', 'teacher', 'students'],
#  ['best', 'way', 'lose', '30', 'pounds', '4', 'months'],
#  ['world', 'bank', 'helping', 'underprivileged', 'people', 'gimmick'],
#  ['cannot',
#   'multicellular',
#   'organisms',
#   'divide',
#   'like',
#   'unicellular',
#   'organisms'],
#  ['dreams',
#   'dreaming',
#   'true',
#   'dream',
#   'particular',
#   'person',
#   'person',
#   'feel',
#   'like',
#   'miss'],
#  ['favourite', 'metallica', 'song'],
#  ['type', 'government', 'guatemala', 'compare', 'one', 'canada'],
#  ['get', 'fit', 'get', 'rid', 'body', 'fat'],
#  ['donald', 'trump', 'win', 'years', 'election'],
#  ['send', 'push', 'notification', 'beacon', 'need', 'app'],
#  ['karen',
#   'annoyed',
#   'wasnt',
#   'asked',
#   'back',
#   'second',
#   'indiana',
#   'jones',
#   'film'],
#  ['republican', 'members', 'congress', 'resistant', 'president', 'trump'],
#  ['people',
#   'actually',
#   'like',
#   'taste',
#   'beer',
#   'consume',
#   'get',
#   'drunk',
#   'reasons',
#   'possible',
#   'people',
#   'pretend',
#   'like',
#   'beer',
#   'social',
#   'pressure'],
#  ['demographics', 'wall', 'street', 'professionals', 'new', 'york', 'city'],
#  ['tasty', 'way', 'repurpose', 'leftover', 'fried', 'calamari'],
#  ['get', 'online', 'mobile', 'income'],
#  ['total',
#   'number',
#   'peerreviewed',
#   'articles',
#   'published',
#   'science',
#   'journal'],
#  ['offline', 'shown', 'display', 'viber', 'one', 'talking', 'phone'],
#  ['happy', 'life'],
#  ['stop', 'mentally', 'abusive', 'relationship', 'parents'],
#  ['activities', 'housewives', 'free', 'time', 'make', 'efficient', 'use'],
#  ['lose', '10', 'kilos'],
#  ['google', 'hangouts', 'use', 'data'],
#  ['boys', 'haircut', 'called'],
#  ['american', 'big', 'cities', 'disrespectful'],
#  ['reservation', 'status', 'rac', 'mean', 'seat', 'confirmed'],
#  ['sony', 'led', 'tvs', 'worth', 'buying'],
#  ['ever', 'back', 'death'],
#  ['kelly', 'anne', 'conway', 'slim', 'despite', 'four', 'kids'],
#  ['girls', 'psychology', 'typical', 'complicated'],
#  ['stop', 'premature', 'graying', 'hairs', 'hair', 'loss'],
#  ['best', 'mobile', 'buy', 'rs', '7k'],
#  ['procedure', 'apply', 'articleship', 'big', 'four'],
#  ['best', 'place', 'stay', 'bangalore'],
#  ['things', 'shouldnt', 'miss', 'watch', 'delhi'],
#  ['quora', 'change', 'generic', 'blue', 'profile', 'photo'],
#  ['highlight',
#   'specific',
#   'influences',
#   'plato',
#   'augustine',
#   'aristotle',
#   'formation',
#   'aquinas',
#   'worldview'],
#  ['coolest', 'thing', 'best', 'friends', 'boy', 'birthday'],
#  ['give', 'simple', 'definition', 'gini', 'index'],
#  ['best', 'way', 'make', 'money'],
#  ['wear', 'perfume'],
#  ['reverse', 'linked', 'list', 'javascript'],
#  ['police', 'subculture', 'us'],
#  ['could', 'improve', 'english', 'pronunciation'],
#  ['whats', 'best', 'time', 'sex'],
#  ['computer', 'programmers', 'make', 'money'],
#  ['pros', 'cons', 'late', 'marriage'],
#  ['difference', 'fellow', 'student', 'schoolmate'],
#  ['nothing'],
#  ['cure', 'vitiligo'],
#  ['good',
#   'idea',
#   'guarantee',
#   'anonymity',
#   'qa',
#   'communities',
#   'like',
#   'quora'],
#  ['nonmutual',
#   'friends',
#   'see',
#   'facebook',
#   'common',
#   'friend',
#   'likes',
#   'comments'],
#  ['passed',
#   'mechanical',
#   'real',
#   'hard',
#   'time',
#   'finding',
#   'job',
#   'core',
#   'natural',
#   'happen'],
#  ['asus', 'zenfone', '2', 'ze550ml', 'provide', 'update'],
#  ['one', 'earn', 'money', 'online', 'without', 'investment', 'home'],
#  ['pokemon', 'ranger', 'temple', 'manaphy', 'annoying'],
#  ['scjp', 'certification', 'beneficial', 'professional', 'career', 'growth'],
#  ['think',
#   'karan',
#   'johar',
#   'paid',
#   'kamaal',
#   'r',
#   'khan',
#   '25',
#   'lacs',
#   'praise',
#   'movie',
#   'ae',
#   'dil',
#   'mushkil',
#   'bash',
#   'shivaay'],
#  ['become', 'commercial', 'pilot', 'hawaii'],
#  ['pakistan',
#   'cricket',
#   'team',
#   'unpredictable',
#   'cricket',
#   'team',
#   'west',
#   'indies',
#   'cricket',
#   'team'],
#  ['people',
#   'ask',
#   'questions',
#   'whose',
#   'answer',
#   'easily',
#   'found',
#   'internet'],
#  ['mean',
#   'feelings',
#   'emptiness',
#   'person',
#   'borderline',
#   'personality',
#   'disorder'],
#  ['best', 'platformmediasource', 'learn', 'digital', 'marketing'],
#  ['name', 'apps', 'get', 'list', 'doctors', 'providing', 'discounts'],
#  ['porn', 'ruins', 'ones', 'sex', 'life'],
#  ['starting', 'gaming', 'channel', 'youtube', 'good', 'name', 'channel'],
#  ['become', 'great', 'quizzer'],
#  ['cookie', 'mean', 'slang', 'term'],
#  ['score', '100', 'clat', 'able', 'get', 'nujs'],
#  ['know', 'married', 'loves', 'even', 'married'],
#  ['functions', 'imf'],
#  ['examples', 'doublethink'],
#  ['showroom', 'price', 'tata', '407', 'allahabad'],
#  ['ancient', 'egyptian', 'language', 'semitic', 'language'],
#  ['sunglasses', 'secret', 'service', 'agents', 'wear'],
#  ['put',
#   'money',
#   'value',
#   'social',
#   'economic',
#   'benefits',
#   'product',
#   'seem',
#   'bit',
#   'intangible',
#   'direct'],
#  ['review', 'fiskebäckskil', 'sweden'],
#  ['demonetization', 'scam'],
#  ['melania', 'trumps', 'plagiarism', 'intentional'],
#  ['got',
#   'upset',
#   'knowing',
#   'hindu',
#   'gods',
#   'said',
#   'satanic',
#   'bible',
#   'one',
#   'roommates',
#   'true'],
#  ['find', 'large', 'datasets', 'open', 'public'],
#  ['would',
#   'possible',
#   'use',
#   'photons',
#   'instead',
#   'electrons',
#   'electric',
#   'current',
#   'run',
#   'motor',
#   '',
#   'create',
#   'motor',
#   'runs',
#   'photons',
#   'instead'],
#  ['best', 'remedy', 'arthritis'],
#  ['decoder', 'applications'],
#  ['really',
#   'need',
#   'micro',
#   'sim',
#   'adapter',
#   'put',
#   'nano',
#   'sim',
#   'card',
#   'samsung',
#   'galaxy',
#   's3'],
#  ['mandarin',
#   'course',
#   'introduced',
#   'schools',
#   'isnt',
#   'nepal',
#   'missing',
#   'world',
#   'economic',
#   'opportunity',
#   'learning',
#   'mandarin'],
#  ['hollywood',
#   'actors',
#   'actresses',
#   'really',
#   'engage',
#   'sexual',
#   'intercourse',
#   'shooting',
#   'sex',
#   'scenes'],
#  ['good', 'business', 'ideas', 'low', 'investment', 'india'],
#  ['turkey', 'safe', 'visit', 'given', 'recent', 'set', 'news', 'bombings'],
#  ['new', 'technology'],
#  ['dslr', 'camera', 'better', 'nikon', 'd3300', 'canon', 'eos', '1300d'],
#  ['download',
#   'free',
#   'planogram',
#   'software',
#   'use',
#   'monitor',
#   'items',
#   'displayed'],
#  ['dogs', 'wag', 'tails', 'happy'],
#  ['difference', 'thermodynamics', 'heat', 'transfer'],
#  ['learn', 'failures'],
#  ['someone', 'deal', 'office', 'politics'],
#  ['cant', 'see', 'likes', 'persons', 'facebook', 'status'],
#  ['main', 'benefits', 'political', 'stability'],
#  ['kevin', 'mchale', 'really', 'disabled', 'prepare', 'role', 'glee'],
#  ['students', 'josaacsab', 'conducts', 'special', 'round', 'counselling'],
#  ['one', 'become', 'dentist', 'germany'],
#  ['many', 'total', 'pokémon'],
#  ['wrong', 'hiring', 'process'],
#  ['one', 'figure', 'purpose'],
#  ['march', '6th', '2015', 'good', 'time', 'buy', 'apple', 'stock'],
#  ['dont',
#   'people',
#   'know',
#   'boyz',
#   'gave',
#   'many',
#   'hit',
#   'songs',
#   'bollywood'],
#  ['whats', 'deal', 'count', 'dooku', 'darth', 'sidious'],
#  ['find', 'someone', 'picture'],
#  ['combat', 'social', 'anxiety'],
#  ['songs', 'best', 'bass', 'drops'],
#  ['whos', 'father'],
#  ['employees',
#   'comfort',
#   'systems',
#   'good',
#   'worklife',
#   'balance',
#   'differ',
#   'across',
#   'positions',
#   'departments'],
#  ['acceptance',
#   'rate',
#   'harvard',
#   'electrical',
#   'engineering',
#   'international',
#   'students'],
#  ['possible', 'find', 'whether', 'girl', 'virgin', 'first', 'night'],
#  ['batman',
#   'superman',
#   'didnt',
#   'superman',
#   'save',
#   'mother',
#   'warehouse',
#   'lexs'],
#  ['acronym',
#   'sipde',
#   'scan',
#   'identify',
#   'predict',
#   'decide',
#   'execute',
#   'created'],
#  ['good', 'ted', 'talks'],
#  ['feel', 'like', 'enlightened'],
#  ['winning', 'money', 'youtube'],
#  ['quoran',
#   'millions',
#   'views',
#   'poor',
#   'exchange',
#   'view',
#   'forget',
#   'knowledge',
#   'becomea',
#   'farmerdo',
#   'accept'],
#  ['beautiful', 'woman', 'ever', 'saw'],
#  ['write', 'research'],
#  ['suitable',
#   'inpatient',
#   'drug',
#   'alcohol',
#   'rehab',
#   'center',
#   'tallapoosa',
#   'county'],
#  ['indians', 'americans', 'active', 'quora'],
#  ['food', 'coloring'],
#  ['ove', 'universal', 'donor'],
#  ['key', 'traits', 'mentally', 'strong', 'people'],
#  ['much', 'youtube', 'pay', '1000', 'views', 'iraq'],
#  ['top', 'ten', 'movies', 'language', 'genre', 'one', 'watch', 'lifetime'],
#  ['good', 'computer', 'science', 'seminar', 'topics', 'currently', 'relevant'],
#  ['become',
#   'pilot',
#   'aeronautical',
#   'engineering',
#   'increase',
#   'job',
#   'probability',
#   'late',
#   'become',
#   'pilot'],
#  ['creative', 'engineer'],
#  ['biggest', 'mistake', 'made'],
#  ['parallelterm',
#   'means',
#   'computer',
#   'processing',
#   'list',
#   'briefly',
#   'define',
#   'types',
#   'computer',
#   'system',
#   'organization'],
#  ['kind', 'software', 'applications', 'hospitals', 'use'],
#  ['give', 'videos', 'nolanish', 'feel'],
#  ['klinefelter', 'syndrome'],
#  ['evidence', 'god', 'exists', 'evidence', 'doesnt'],
#  ['xamarin', 'best', 'cross', 'platform', 'mobile', 'development', 'tool'],
#  ['views',
#   'india',
#   'banning',
#   '500',
#   '1000',
#   'notes',
#   'way',
#   'affect',
#   'indian',
#   'economy'],
#  ['recent', 'dreams', 'love', 'mean'],
#  ['disappointed', 'decisions', 'youve', 'made', 'past'],
#  ['possible', 'time', 'travel', 'past'],
#  ['advantages', 'setting', 'anonymous', 'feedback', 'form'],
#  ['would', 'absolute', 'hardest', 'country', 'launch', 'invasion'],
#  ['consistently', 'losing', 'followers', 'instagram'],
#  ['best', 'site', 'download', 'songs'],
#  ['gorillas', 'chimpanzees', 'dangerous'],
#  ['abilities', 'mind'],
#  ['would',
#   'good',
#   'age',
#   'start',
#   'reading',
#   'shakespeares',
#   'plays',
#   'child'],
#  ['best', 'ide'],
#  ['camera', 'took', 'picture', 'worlds', 'first', 'camera'],
#  ['take',
#   'bath',
#   'breakfastlunch',
#   'okay',
#   'take',
#   'bath',
#   'evening',
#   'morning'],
#  ['prepare', 'chemistry', 'bitsat'],
#  ['buying', 'cracking', 'coding', 'interview', 'really', 'worth'],
#  ['current',
#   'job',
#   'scenario',
#   'metallurgical',
#   'engineering',
#   'field',
#   'india',
#   'graduates'],
#  ['best', 'phone', '20000', 'india', 'right', '2016'],
#  ['relationship', 'antigens', 'antibodies'],
#  ['things', 'people', 'around', 'irritate'],
#  ['mahatma', 'gandhi', 'hated', 'india'],
#  ['release', 'transcripts'],
#  ['communications', 'manager'],
#  ['side',
#   'effects',
#   'riding',
#   'car',
#   '5th',
#   'gear',
#   'low',
#   'speed',
#   '4050',
#   'kmph',
#   'riding',
#   'high',
#   'speed',
#   'low',
#   'gear',
#   '50',
#   'kmph',
#   '3',
#   'rd',
#   'gear'],
#  ['significance', 'battle', 'battle', 'compare', 'contrast', 'battle', 'mill'],
#  ['lord', 'krishna', 'accept', 'radhas', 'love'],
#  ['believe', 'life', 'death'],
#  ['get', 'android', 'developer', 'job', 'htc'],
#  ['people', 'lesswrong', 'autoadmit', 'think'],
#  ['nickname', 'air', 'force'],
#  ['narendra',
#   'modi',
#   'tell',
#   'cannot',
#   'get',
#   'involved',
#   'cauvery',
#   'river',
#   'water',
#   'dispute'],
#  ['company', 'makes', 'better', 'graphics', 'cards', 'nvidia', 'amd'],
#  ['issues', 'faced', 'users', 'reliance', 'jio', 'free', 'trial'],
#  ['best', 'way', 'clean', 'engine'],
#  ['procedure', 'becoming', 'rto', 'officer'],
#  ['advantages', 'wooden', 'pencils', 'mechanical', 'pencils'],
#  ['think',
#   'reason',
#   'pm',
#   'modis',
#   'instant',
#   'decision',
#   'ban',
#   '500',
#   '1000',
#   'notes'],
#  ['take', 'iq', 'test', 'internet', 'free'],
#  ['neil', 'armstrong', 'genius'],
#  ['significance', 'fourteenth', 'amendment'],
#  ['switching', 'windows', 'linux', 'know'],
#  ['instances', 'team', 'test', 'match', 'even', 'getting', '20', 'wickets'],
#  ['doubt', 'hair', 'removal', 'use', 'veet', 'remove', 'pubic', 'hair'],
#  ['learning', 'neural', 'network'],
#  ['hotel',
#   'jamshedpur',
#   'would',
#   'safe',
#   'unmarried',
#   'couples',
#   'without',
#   'harassment',
#   'police',
#   'hotel',
#   'staff',
#   'moral',
#   'police'],
#  ['difference', 'nephew', 'niece'],
#  ['develop', 'positive', 'attitude'],
#  ['get', 'rid', 'acne', 'acne', 'causes'],
#  ['imminent', 'world', 'iii'],
#  ['productive',
#   'marketing',
#   'strategy',
#   'channel',
#   'saas',
#   '10',
#   'million',
#   'revenue',
#   'reduces',
#   'customer',
#   'acquisition',
#   'cost'],
#  ['prepare', 'upsc', 'gs4'],
#  ['best', 'websites', 'programmer', 'visit'],
#  ['happen',
#   'india',
#   'pakistan',
#   'could',
#   'impact',
#   'indian',
#   'economy',
#   'stock',
#   'market'],
#  ['natural', 'remedy', 'losing', 'body', 'hair'],
#  ['control', 'emotions'],
#  ['criticisms', 'windows', '10'],
#  ['get', 'traffic', 'site'],
#  ['raised', 'power', 'infinity'],
#  ['emblems', 'emir', 'mohammed', 'alim', 'khan', 'wear', 'lapel', 'pins'],
#  ['find', 'cure', 'muscular', 'dystrophy'],
#  ['best', 'prank', 'pulled', 'kid'],
#  ['revert',
#   'back',
#   'original',
#   'colour',
#   'got',
#   'light',
#   'colou',
#   'r',
#   'got',
#   'dark',
#   'medication',
#   'pneumoni',
#   'typhoid',
#   'sun'],
#  ['whats', 'good', 'workout', 'plan', 'lose', 'belly', 'fat'],
#  ['constantly', 'losing', 'concentration', 'going', 'studies'],
#  ['safe', 'bake', 'aluminum', 'foil'],
#  ['long', 'keep', 'instagram', 'account', 'deactivated', 'gets', 'deleted'],
#  ['interesting', 'programming', 'language'],
#  ['usps', 'deliver', 'mail', 'weekends'],
#  ['cant', 'someone', 'stop', 'thinking'],
#  ['wave', 'electronics'],
#  ['currency', 'demonetisation', 'affect', 'common', 'india'],
#  ['whats', 'quickest', 'way', 'earn', 'money', 'online'],
#  ['measure', 'height', 'mountain'],
#  ['existed', 'beginning', 'time'],
#  ['locate', 'local', 'venus', 'swimwear', 'store', 'area', 'online', 'us'],
#  ['spanish', 'inquisition', 'cause', 'rise', 'nonbelievers'],
#  ['much', 'smoking', 'causes', 'miscarriage'],
#  ['derivative', 'respect', 'x', 'mathx', 'sinyy', 'cosx0', 'math'],
#  ['expected', 'salary', 'company', 'secretary'],
#  ['ancient', 'india', 'ever', 'conquer', 'civilizations'],
#  ['much', 'ifs', 'officer', 'get', 'paid'],
#  ['required', 'open', 'branch', 'rural', 'urban', 'cooperative', 'bank'],
#  ['add', 'geolocation', 'data', 'photo', 'photo', 'taken'],
#  ['fun',
#   'activities',
#   'group',
#   'kids',
#   'learn',
#   'selfconfidence',
#   'performing',
#   'stage'],
#  ['best', 'pc', 'games', 'played', 'laptop'],
#  ['get', 'list', 'individual', 'telephone', 'numbers'],
#  ['lactic', 'acid', 'ferment'],
#  ['prefer',
#   'women',
#   'without',
#   'makeup',
#   'really',
#   'true',
#   'prefer',
#   'women',
#   'wear',
#   'less',
#   'makeup'],
#  ['greatest', 'invention', 'made', 'indian'],
#  ['best', 'speaker', 'company'],
#  ['best', 'way', 'market', 'novel'],
#  ['people', 'concerned', 'whether', 'god', 'exists'],
#  ['automobile', 'engineering', 'srm'],
#  ['possible',
#   'become',
#   'intelligent',
#   'late',
#   'twenties',
#   'spending',
#   'quater',
#   'life',
#   'average'],
#  ['learn', 'people', 'think'],
#  ['ip',
#   'layer',
#   'need',
#   'check',
#   'packages',
#   'link',
#   'level',
#   'already',
#   'done'],
#  ['energy', 'neither', 'created', 'destroyed', 'created', 'energy'],
#  ['long', 'take', 'repair', 'extremely', 'damaged', 'hair'],
#  ['food', 'tech', 'start', 'ups', 'hiring', 'bangalore'],
#  ['sell',
#   'technology',
#   'products',
#   'especially',
#   'internet',
#   'data',
#   'center',
#   'hosting'],
#  ['', 'algorithm', 'behind', 'app', 'like', 'summly'],
#  ['boot'],
#  ['indian', 'state', 'jammu', 'kashmir', 'two', 'capitals'],
#  ['lived', '26years', 'mother', 'sick'],
#  ['differences',
#   'post',
#   'synaptic',
#   'density',
#   'excitatory',
#   'vs',
#   'inhibitory',
#   'synapses'],
#  ['rt', 'news', 'channel', 'biased', 'western', 'media', 'would', 'believe'],
#  ['natural', 'ways', 'increase', 'height', 'age', '23'],
#  ['cost', '2', 'mbps', 'leased', 'line', 'india', '11', 'ratio'],
#  ['story',
#   'behind',
#   'swastika',
#   'hindu',
#   'symbol',
#   'resemblance',
#   'nazi',
#   'symbol',
#   'coincidence'],
#  ['best', 'way', 'get', 'gold', 'fish', 'neko', 'atsume'],
#  ['great', 'vegetable', 'side', 'dish', 'recipes', 'thanksgiving', 'dinner'],
#  ['constitutes', 'true', 'beauty'],
#  ['qualities',
#   'would',
#   'glass',
#   'cinderellas',
#   'slippers',
#   'need',
#   'order',
#   'walk',
#   'dance',
#   'comfortably',
#   'hold',
#   'weight'],
#  ['americans', 'refer', 'obamas', 'presidency', 'scary'],
#  ['jimi', 'hendrix'],
#  ['switch', 'screen', 'overlay', 'moto', 'g4plus'],
#  ['know', 'found', 'one'],
#  ['donald', 'trump', 'really', 'racist'],
#  ['worth', 'upgrading', 'iphone', '6s', 'plus', 'iphone', '7', 'plus'],
#  ['importance', 'yesterday'],
#  ['cpu', 'actually'],
#  ['best', 'place', 'learn', 'spanish', 'online'],
#  ['correct', 'errors', 'indesign', 'pages'],
#  ['hillary', 'disbarred'],
#  ['complete', 'sentence'],
#  ['intelligence', 'blessing', 'curse'],
#  ['start', 'small', 'business', 'developing', 'country'],
#  ['creamy', 'layer', 'noncreamy', 'layer', 'obc', 'category'],
#  ['effective', 'marketing', 'strategies', 'startups'],
#  ['feel',
#   'like',
#   'get',
#   'less',
#   'opportunity',
#   'film',
#   'industry',
#   'beacuse',
#   'short',
#   'due',
#   'depressionwhat'],
#  ['stop', 'whining', 'getting', 'spayed'],
#  ['throwing', 'yellowwhite', 'liquidfoam'],
#  ['fear',
#   'career',
#   'path',
#   'exist',
#   'decades',
#   'loses',
#   'value',
#   'society',
#   'robotics',
#   'make',
#   'obsolete'],
#  ['become', 'astronaut'],
#  ['create', 'twitter', 'account', 'without', 'phone', 'verification'],
#  ['melt', 'peanut', 'butter', 'peanut', 'butter', 'made'],
#  ['follow', 'mean', 'quora'],
#  ['best', 'viral', 'videos'],
#  ['donald', 'trump', 'become', 'dictator'],
#  ['differences', 'java', 'serialization', 'hadoop', 'serialization'],
#  ['somewhere', 'host', 'django', 'web', 'app', 'free'],
#  ['genius',
#   'bar',
#   'apple',
#   'check',
#   'devices',
#   'battery',
#   'say',
#   'battery',
#   'isnt',
#   'working',
#   'ask',
#   'replacement'],
#  ['start', 'relationship'],
#  ['banking', 'much', 'currency', 'country', 'print'],
#  ['pubic', 'hair', 'evolve', 'humans'],
#  ['passive', 'form'],
#  ['moocs',
#   'developed',
#   'universities',
#   'spain',
#   'similar',
#   'edx',
#   'coursera',
#   'khan',
#   'academy',
#   'nptel',
#   'ocw'],
#  ['halloween', 'like', '1990s'],
#  ['much',
#   'cost',
#   'gas',
#   'station',
#   'canada',
#   'much',
#   'make',
#   'year',
#   'employ',
#   'people',
#   'run'],
#  ['hvr1', 'section', 'mtdna'],
#  ['several',
#   'cars',
#   'like',
#   'tushek',
#   'spigal',
#   'giving',
#   'power',
#   'people',
#   'aint',
#   'opting'],
#  ['intermission', 'hockey', 'affect', 'hockey', 'match'],
#  ['role', 'vp', 'menon', 'partition', 'integration', 'india'],
#  ['america',
#   'declare',
#   'pakistan',
#   'terrorist',
#   'country',
#   'petition',
#   'already',
#   'got',
#   'record',
#   'support'],
#  ['camera',
#   'app',
#   'lumia',
#   '535',
#   'shows',
#   'thumbnail',
#   'deleted',
#   'picturehow',
#   'remove'],
#  ['salad', 'finger'],
#  ['rich',
#   'keep',
#   'getting',
#   'richer',
#   'poor',
#   'keep',
#   'getting',
#   'poorer',
#   'india'],
#  ['scored',
#   '215',
#   'neet',
#   '2016',
#   'sc',
#   'candidate',
#   'get',
#   'admission',
#   'private',
#   'college'],
#  ['orange', 'evening'],
#  ['whats',
#   'origin',
#   'eating',
#   'motion',
#   'see',
#   'many',
#   'college',
#   'football',
#   'players',
#   'making',
#   'good',
#   'play',
#   'like',
#   'first'],
#  ['difference', 'honda', 'accord', 'lx', 'ex'],
#  ['best', 'mobile', 'app', 'development', 'company'],
#  ['get', 'internship', 'iits', 'ug', 'student'],
#  ['people', 'say', 'hillary', 'clinton', 'crook'],
#  ['tips', 'preparations', '10th', 'board', 'exams'],
#  ['mostused', 'command', 'lines', 'command', 'prompts', 'ethical', 'hacking'],
#  ['become', 'software', 'engineer', 'classes', 'take', 'high', 'school'],
#  ['quit', 'smoking'],
#  ['best', 'compiler', 'python'],
#  ['deal', 'jealousy'],
#  ['fix', 'fear', 'fighting'],
#  ['fact', 'history', 'majors', 'believe', 'holocaust', 'refutation'],
#  ['ex', 'still', 'talks', 'still', 'hope', 'get', 'back', 'together'],
#  ['best', 'resources', 'applying', 'music', 'graduate', 'degree'],
#  ['adam', 'sandlers', 'movies', 'bad'],
#  ['spanish', 'word', 'nothing'],
#  ['ways', 'overcome', 'fear', 'fighting'],
#  ['alexander',
#   'great',
#   'really',
#   'say',
#   'ufo',
#   'attacked',
#   'city',
#   'walls',
#   'tyre',
#   'lead',
#   'citys',
#   'defeat'],
#  ['best', 'interview', 'questions'],
#  ['people', 'try', 'make', 'someone', 'commits', 'suicide'],
#  ['best', 'way', 'prepare', 'bitsat', 'jee', '2', '4', 'weeks', 'remaining'],
#  ['qualities', 'great', 'leader'],
#  ['best', 'mobile', 'windows', 'android'],
#  ['dancing', 'types', 'bar', 'nightclubs'],
#  ['quora',
#   'unable',
#   'compete',
#   'stack',
#   'overflow',
#   'programming',
#   'questions'],
#  ['start', 'private', 'equity', 'firm'],
#  ['good',
#   'studies',
#   'placement',
#   'electrical',
#   'computer',
#   'department',
#   'northeastern',
#   'university'],
#  ['five', 'facts', 'asthenosphere'],
#  ['white', 'lies', 'good'],
#  ['email', 'notice', 'valid'],
#  ['write', 'essay'],
#  ['sort', 'person', 'wears', 'sandals', 'socks'],
#  ['mean', 'see', 'dream', 'twice'],
#  ['top', '3', 'important', 'android', 'phone', 'apps'],
#  ['reason',
#   'behind',
#   'resignation',
#   'tata',
#   'sons',
#   'tata',
#   'group',
#   'chairman',
#   'cyrus',
#   'mistry'],
#  ['read', 'friends', 'whatsapp', 'chat', 'without', 'taking', 'phone'],
#  ['lokpal', 'bill', 'passed'],
#  ['motivate', 'crew'],
#  ['wwf', 'become', 'wwe'],
#  ['best', 'user', 'friendly', 'video', 'editing', 'softwares', 'tool'],
#  ['pronouncing',
#   'word',
#   'military',
#   'americans',
#   'say',
#   'milluhtarry',
#   'english',
#   'say',
#   'milluhtree'],
#  ['bajaj',
#   'avenger',
#   '220',
#   'street',
#   '',
#   'considering',
#   'low',
#   'height',
#   'bike',
#   'suitable',
#   '6',
#   'feet',
#   'tall',
#   'guy'],
#  ['indian', 'move', 'mexico', 'absolutely', 'blend'],
#  ['strongest',
#   'majors',
#   'terms',
#   'job',
#   'prospects',
#   'weakest',
#   'majors',
#   'ball',
#   'state'],
#  ['vaping', 'without', 'nicotine', 'bad'],
#  ['universe', 'look', 'like', 'big', 'bang'],
#  ['gain', 'weight', 'month', ''],
#  ['99dressescom', 'get', 'initial', 'traction'],
#  ['use', 'polyvore', 'images', 'website'],
#  ['beef', 'halal'],
#  ['indian', 'muslims', 'hate', 'narendra', 'modi'],
#  ['deepest',
#   'lake',
#   'europe',
#   'lakes',
#   'flora',
#   'fauna',
#   'compare',
#   'lake',
#   'fianga'],
#  ['best', 'way', 'successful', 'life'],
#  ['quora', 'prevent', 'asking', 'anonymous', 'questions'],
#  ['suddenly',
#   'manage',
#   'answer',
#   'questions',
#   'related',
#   'negative',
#   'energy',
#   'fully',
#   'advance',
#   'field',
#   'would',
#   'affect',
#   'us',
#   'terms',
#   'technological',
#   'advancements'],
#  ['time', 'leaps', 'acceptable', 'novel', 'writing'],
#  ['best', 'hindi', 'movie', '2016'],
#  ['main',
#   'reason',
#   'discontinuing',
#   '500',
#   '1000',
#   'rupees',
#   'note',
#   'india',
#   'pros',
#   'cons'],
#  ['cool', 'things'],
#  ['allopatric', 'sympatric', 'speciation'],
#  ['one', 'fall', 'love'],
#  ['watch', 'sherlock', 'season', '4', 'online'],
#  ['capricorn', 'cheat'],
#  ['causes', 'eyes', 'look', 'like', 'change', 'color', 'blue', 'green'],
#  ['best', 'trucking', 'movies'],
#  ['way', 'survive', '50', 'ae', 'desert', 'eagle', 'shot', 'eyes'],
#  ['cloud', 'computing', 'work'],
#  ['reheat', 'omelette'],
#  ['us', 'army', 'build', 'base', 'top', 'babylon'],
#  ['consequences', 'crusades'],
#  ['wrong', 'girl', 'confess', 'feeling', 'towards', 'boy'],
#  ['become', 'trainee', 'solicitor'],
#  ['women',
#   'think',
#   'security',
#   'first',
#   'love',
#   'feelings',
#   'someone',
#   'proposes'],
#  ['pm', 'india', 'bring', 'black', 'money', 'swiss', 'bank', 'accounts'],
#  ['one', 'ejaculate', 'without', 'achieving', 'orgasm'],
#  ['many', 'sectors', 'tcs', 'cse', 'students'],
#  ['documents',
#   'required',
#   'transfer',
#   'sbi',
#   'savings',
#   'account',
#   'one',
#   'city',
#   'another',
#   'city'],
#  ['people', 'move', 'one', 'mbti', 'another', 'time', 'experience'],
#  ['learn', 'two', 'programming', 'languages'],
#  ['gas',
#   'leak',
#   'kill',
#   'breathing',
#   'know',
#   'cause',
#   'explosion',
#   'kill',
#   'around',
#   'fills',
#   'house'],
#  ['amniotic', 'fluid'],
#  ['healthy', 'foods', 'gain', 'weight'],
#  ['make', 'money', 'internet', 'time'],
#  ['examples', 'governement', 'markets'],
#  ['sex', 'stranger'],
#  ['saltwater', 'taffy', 'candy', 'imported', 'czech', 'republic'],
#  ['handsome', 'better', 'cute'],
#  ['indian', 'girls', 'boys', 'outgoing'],
#  ['could', 'speak', '16', 'yearold', 'self', 'would', 'say'],
#  ['get', 'rid', 'acne', 'naturally'],
#  ['birds', 'stay', 'place', 'fly'],
#  ['make', 'effectively', 'styled', 'resume'],
#  ['inspiron',
#   '5000',
#   'series',
#   'slow',
#   'bought',
#   'last',
#   'christmas',
#   'nothing'],
#  ['harvard',
#   'risk',
#   'management',
#   'corp',
#   'contacted',
#   'sales',
#   'position',
#   'selling',
#   'identity',
#   'theft',
#   'protection',
#   'company',
#   'legitimate'],
#  ['breaking', 'bad', 'ever', 'happened', 'ted', 'beneke'],
#  ['loss', 'humanity'],
#  ['steak', 'gluten', 'free'],
#  ['think', 'god', 'would', 'happy', 'seeing', 'behaviour'],
#  ['start', 'online', 'business'],
#  ['effect', 'donald', 'trump', 'becoming', 'president', 'us', 'india'],
#  ['capital', 'reduction'],
#  ['wrongly', 'sent', 'text', 'boss', 'whats', 'next'],
#  ['16th', 'birthday', 'male'],
#  ['supporting', 'donald', 'trump', 'makes', 'put', 'vote', 'donald', 'trump'],
#  ['least', 'favorite', 'starter', 'pokemon'],
#  ['unfriend',
#   'someone',
#   'facebook',
#   'would',
#   'still',
#   'able',
#   'see',
#   'past',
#   'likes',
#   'comments',
#   'page'],
#  ['difference',
#   'python',
#   'scripting',
#   'objectoriented',
#   'python',
#   'sevelopment'],
#  ['tennis',
#   'grand',
#   'slam',
#   'draws',
#   'determined',
#   'question',
#   'arised',
#   'realised',
#   'never',
#   'seen',
#   'federer',
#   'nadal',
#   'compete',
#   'first',
#   'round',
#   'match'],
#  ['find', 'hotels', 'new', 'york', 'city', 'allow', 'smoking'],
#  ['phone', 'use'],
#  ['change', 'lose', 'weight'],
#  ['role', 'imperative', 'argument'],
#  ['best', 'songs', 'sing'],
#  ['convert', 'hz', 'nm'],
#  ['likely', 'elected', 'president', 'hillary', 'trump'],
#  ['woman', 'history', 'would', 'almost', 'alive', 'today', 'fall', 'love'],
#  ['quora', 'allow', 'others', 'edit', 'questions'],
#  ['professional', 'ethics'],
#  ['delete', 'account', 'instagram', 'cant', 'remember', 'password', 'email'],
#  ['email', 'address', 'use', 'create', 'linkedin', 'account'],
#  ['best', 'way', 'learn', 'web', 'designing'],
#  ['demand', 'aws', 'certification'],
#  ['good', 'action', 'games', 'pc'],
#  ['best', 'place', 'stay', 'visit', 'kerala'],
#  ['get', 'rid', 'acne', 'scars'],
#  ['sure', 'love', 'best', 'friend'],
#  ['happened',
#   'famous',
#   'singapore',
#   'blogger',
#   'phd',
#   'stanford',
#   'driving',
#   'taxi',
#   'losing',
#   'research',
#   'job'],
#  ['history', 'korean', 'dramas'],
#  ['meaning', 'kala', 'pani', 'saza', 'hindi'],
#  ['latest', 'page', 'activities', 'seo'],
#  ['prevent', 'stress'],
#  ['may',
#   'possible',
#   'future',
#   'software',
#   'industry',
#   'respect',
#   'software',
#   'piracy'],
#  ['part', 'mexico', 'play', 'world', 'two'],
#  ['ambani', 'attend', 'wharton'],
#  ['crime', 'rate', 'borough', 'ealing', 'compare', 'barnet'],
#  ['one', 'bring', 'person', 'back', 'life'],
#  ['hiv', 'transmit', 'small', 'cut', 'finger'],
#  ['thing', 'slow', 'carb', 'diet', 'vegans'],
#  ['difference', 'smo', 'seo'],
#  ['difference',
#   'indian',
#   'official',
#   'passport',
#   'indian',
#   'diplomatic',
#   'passport'],
#  ['best', 'way', 'invest', '10', 'lakh', 'rupees', 'india'],
#  ['appsbarcom'],
#  ['startup',
#   'patna',
#   'bihar',
#   'connect',
#   'investors',
#   'invest',
#   'capital',
#   'new',
#   'startup'],
#  ['high', 'airplanes', 'fly'],
#  ...]

# %%
def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
tsne_plot(model)
# Out:
# /home/sarthak/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys
